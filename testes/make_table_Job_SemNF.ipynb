# %%
# metodo de tratar tabelas

# %%
import os
import get_file_word as gf
import datetime
import pandas as pd

#setar variáveis onde estão arquivos
fileExt = r".docx"
fileExt2 = r".doc"

fileDir_semNF = r"/Users/wpessoa/repositorios/NGE/words_semNota/"

# verificar se existe o diretório
print("Existe esse diretório? ",os.path.exists(fileDir_semNF)) 
files_array_semNF = [_ for _ in os.listdir(fileDir_semNF) if _.endswith(fileExt)]
print("Quantidade de arquivos do word no diretório: ",len(files_array_semNF)) # ARQUIVOS DOCX

# rodar método get_info para ler aquivos do Word e retornar features de cada arquivo
# argumentos (diretório e array dos arquivos word)
# retorna (NºID,Qtd_caracteres,Qtd_tabela,Qtd_image,data)

var_semNF=gf.get_info(fileDir_semNF,files_array_semNF)
# Out:
# Existe esse diretório?  True
# Quantidade de arquivos do word no diretório:  17
# ID235880-AgendaPara_MÇxico_2020_Normalizada (1).docx
# ID235980-Educação Infantil  4 e 5  anos - Diagramar.docx
# ID235985-EF ANOS FINAIS CONSOLIDADO.docx
# ID235905-EstudoRegimeEspecialServicos_NormalizacaoCompleta_20200831.docx
# ID235909-CAMEX_Estudo1_consolidadoAI_normalizado.docx
# ID235876-2020-05-25 AgendaPara_Alemanha_2020_Normalizada TRAD _rev.docx
# ID235798-2020-08-20 MINERACAO NO BRASIL RUMO A UMA INDUSTRIA PRODUTIVA_ SEGURA E SUSTENTA´VEL (1).docx
# ID235986-EF ANOS INICIAIS CONSOLIDADO.docx
# ID235882-AgendaPara_CoreiadoSul_Normalizada (1).docx
# ID235881-AgendaPara_ReinoUnido_Normalizada (1).docx
# ID235964-VF MINUTA DE PUBLICAÇÃO sobre teletrabalho em países selecionados vf rev setembro 04.docx
# ID235878-20200817_Água_de_reúso_Normalizado.docx
# ID235883-AgendaPara_Franáa_Normalizada (1).docx
# ID236021-2020-06-02 AgendaPara_Japao_2020_Normalizada.docx
# ID235979-Educação Infantil  3 anos - Diagramar.docx
# ID235832-2020-08-07 Difusão da I4.0 - Versão para publicação_revisao2.docx
# ID236025-2020-09-16 Concorrência Justa e Defesa Comercial na crise_versão final (1).docx

# %%
# converter veriável de retorno do método para Dataframe
df = pd.DataFrame(var_semNF,columns=['Nº DA PLANILHA',"Qtd_PG_word","Qtd_carac","Qtd_tabela","Qtd_image","Qtd_estilos", "Data"])
df.head()
# Out:
#   Nº DA PLANILHA Qtd_PG_word  Qtd_carac  Qtd_tabela  Qtd_image  Qtd_estilos  \
# 0         235880          26      17783           3          2           23
# 1         235980          11     163469          12         65           15
# 2         235985         424     660609         107         75           27
# 3         235905          75      97635         126         94           54
# 4         235909          38      75538         131         98           21
#
#          Data
# 0  2020-08-26
# 1  2020-09-14
# 2  2020-09-16
# 3  2020-08-31
# 4  2020-09-02

# %%
df
# Out:
#    Nº DA PLANILHA Qtd_PG_word  Qtd_carac  Qtd_tabela  Qtd_image  Qtd_estilos  \
# 0          235880          26      17783           3          2           23
# 1          235980          11     163469          12         65           15
# 2          235985         424     660609         107         75           27
# 3          235905          75      97635         126         94           54
# 4          235909          38      75538         131         98           21
# 5          235876          30      23238         133        107           29
# 6          235798         142     247205         154        130           26
# 7          235986         374     586948         256        138           21
# 8          235882          20      12344         258        140           25
# 9          235881          23      14560         260        142           28
# 10         235964          48      72824         262        144           16
# 11         235878           1      87223         275        156          127
# 12         235883          22      14344         277        158           29
# 13         236021          29      22781         279        160           20
# 14         235979          45      72613         286        207           15
# 15         235832          34      70983         288        211           16
# 16         236025          24      33141         293        216           19
#
#           Data
# 0   2020-08-26
# 1   2020-09-14
# 2   2020-09-16
# 3   2020-08-31
# 4   2020-09-02
# 5   2020-08-21
# 6   2020-08-20
# 7   2020-09-16
# 8   2020-08-26
# 9   2020-08-26
# 10  2020-09-04
# 11  2020-08-17
# 12  2020-08-26
# 13  2020-09-19
# 14  2020-09-14
# 15  2020-08-07
# 16  2020-09-16

# %%
# verificando tipo das variáveis
df.dtypes
# Out:
# Nº DA PLANILHA    object
# Qtd_PG_word       object
# Qtd_carac          int64
# Qtd_tabela         int64
# Qtd_image          int64
# Qtd_estilos        int64
# Data              object
# dtype: object

# %%
# converter tipo para inteiros e data
df["Nº DA PLANILHA"] = pd.to_numeric(df["Nº DA PLANILHA"], errors='coerce')
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Nº DA PLANILHA             int64
# Qtd_PG_word               object
# Qtd_carac                  int64
# Qtd_tabela                 int64
# Qtd_image                  int64
# Qtd_estilos                int64
# Data              datetime64[ns]
# dtype: object

# %%
#Convertendo arquivo excel em dataframe

excelDir ="/Users/wpessoa/repositorios/Fluxo_Editorial/dados/"
excelFile_semNF = pd.read_excel(excelDir+'Exercicio_estimativa_de_paginas_2019_2020.xlsx',"SEM_NOTA_FISCAL")

# %%
len(excelFile_semNF.columns)
# Out:
# 26

# %%
# selecionando apenas colunas necessárias
colunas=['ENTIDADE','PUBLICAÇÃO','Nº de páginas WORD','Nº de páginas estimado', 'COMPLEXIDADE','FORNECEDOR','Nº DA PLANILHA','STATUS DE PGTO']
excelFile2 = excelFile_semNF[colunas]

# %%
excelFile2.columns
# Out:
# Index(['ENTIDADE', 'PUBLICAÇÃO', 'Nº de páginas WORD',
#        'Nº de páginas estimado', 'COMPLEXIDADE', 'FORNECEDOR',
#        'Nº DA PLANILHA', 'STATUS DE PGTO'],
#       dtype='object')

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                  object
# PUBLICAÇÃO                object
# Nº de páginas WORD         int64
# Nº de páginas estimado     int64
# COMPLEXIDADE              object
# FORNECEDOR                object
# Nº DA PLANILHA             int64
# STATUS DE PGTO            object
# dtype: object

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                  object
# PUBLICAÇÃO                object
# Nº de páginas WORD         int64
# Nº de páginas estimado     int64
# COMPLEXIDADE              object
# FORNECEDOR                object
# Nº DA PLANILHA             int64
# STATUS DE PGTO            object
# dtype: object

# %%
excelFile2
# Out:
#    ENTIDADE                                         PUBLICAÇÃO  \
# 0       CNI  Mecanismo de desenvolvimento sustentável e com...
# 1       CNI  A difusão das tecnologias da indústria 4.0 em ...
# 2       CNI                           Financiamento para Clima
# 3       CNI                                 Agenda for Germany
# 4       CNI                   Estudo sobre o impacto econômico
# 5       CNI                               Agenda para o México
# 6       CNI                          Agenda para o Reino Unido
# 7       CNI                               Agenda para a França
# 8       CNI                          Agenda para Coreia do Sul
# 9       CNI                                Mineração no Brasil
# 10      CNI  Proposta de regime para desonerar as importações
# 11      CNI                                         Nova Camex
# 12      CNI                     Teletrabalho no Brasil e mundo
# 13     SESI                           Educação Infantil 3 anos
# 14     SESI                       Educação Infantil 4 e 5 anos
# 15     SESI                                  EJA - Anos Finais
# 16     SESI                                 EJA - Ensino Médio
# 17     SESI                   Ensino Fundamental - Anos Finais
# 18     SESI                 Ensino Fundamental - Anos Iniciais
# 19     SESI                                EJA - Anos Iniciais
# 20      CNI                                   Agenda for Japan
# 21     SESI                 Fortalecimento da defesa comercial
#
#     Nº de páginas WORD  Nº de páginas estimado COMPLEXIDADE FORNECEDOR  \
# 0                   64                      90         Alta   Editorar
# 1                   34                      48        Baixa   Editorar
# 2                   44                      48        Baixa   Editorar
# 3                   30                      48        Baixa   Editorar
# 4                   68                      98         Alta   Editorar
# 5                   26                      48        Baixa   Editorar
# 6                   23                      46        Baixa   Editorar
# 7                   22                      46        Baixa   Editorar
# 8                   20                      46        Baixa   Editorar
# 9                  142                     198         Alta   Editorar
# 10                  75                     110         Alta   Editorar
# 11                  38                      68         Alta   Editorar
# 12                  48                      75         Alta   Editorar
# 13                  45                      70         Alta   Editorar
# 14                  81                     114         Alta   Editorar
# 15                  28                      48        Baixa   Editorar
# 16                  30                      48        Baixa   Editorar
# 17                 424                     460         Alta   Editorar
# 18                 373                     420         Alta   Editorar
# 19                  30                      48        Baixa   Editorar
# 20                  29                      48        Baixa   Editorar
# 21                  24                      48        Baixa   Editorar
#
#     Nº DA PLANILHA STATUS DE PGTO
# 0           235806      Empenhado
# 1           235832      Empenhado
# 2           235874      Empenhado
# 3           235876      Empenhado
# 4           235878      Empenhado
# 5           235880      Empenhado
# 6           235881      Empenhado
# 7           235883      Empenhado
# 8           235882      Empenhado
# 9           235798      Empenhado
# 10          235905      Empenhado
# 11          235909      Empenhado
# 12          235964      Empenhado
# 13          235979      Empenhado
# 14          235980      Empenhado
# 15          235981      Empenhado
# 16          235984      Empenhado
# 17          235985      Empenhado
# 18          235986      Empenhado
# 19          235983      Empenhado
# 20          236021      Empenhado
# 21          236025      Empenhado

# %%
excelFile2.describe()
# Out:
#        Nº de páginas WORD  Nº de páginas estimado  Nº DA PLANILHA
# count           22.000000               22.000000       22.000000
# mean            77.181818              103.318182   235922.363636
# std            107.962796              114.931610       68.385146
# min             20.000000               46.000000   235798.000000
# 25%             28.250000               48.000000   235878.500000
# 50%             36.000000               48.000000   235907.000000
# 75%             67.000000               96.000000   235982.500000
# max            424.000000              460.000000   236025.000000

# %%
# Verificar se tem alguma inconsistencia na planilha Excel - Quantidade de páginas por exemplo
excelFile2.sort_values('Nº de páginas WORD')
# Out:
#    ENTIDADE                                         PUBLICAÇÃO  \
# 8       CNI                          Agenda para Coreia do Sul
# 7       CNI                               Agenda para a França
# 6       CNI                          Agenda para o Reino Unido
# 21     SESI                 Fortalecimento da defesa comercial
# 5       CNI                               Agenda para o México
# 15     SESI                                  EJA - Anos Finais
# 20      CNI                                   Agenda for Japan
# 3       CNI                                 Agenda for Germany
# 19     SESI                                EJA - Anos Iniciais
# 16     SESI                                 EJA - Ensino Médio
# 1       CNI  A difusão das tecnologias da indústria 4.0 em ...
# 11      CNI                                         Nova Camex
# 2       CNI                           Financiamento para Clima
# 13     SESI                           Educação Infantil 3 anos
# 12      CNI                     Teletrabalho no Brasil e mundo
# 0       CNI  Mecanismo de desenvolvimento sustentável e com...
# 4       CNI                   Estudo sobre o impacto econômico
# 10      CNI  Proposta de regime para desonerar as importações
# 14     SESI                       Educação Infantil 4 e 5 anos
# 9       CNI                                Mineração no Brasil
# 18     SESI                 Ensino Fundamental - Anos Iniciais
# 17     SESI                   Ensino Fundamental - Anos Finais
#
#     Nº de páginas WORD  Nº de páginas estimado COMPLEXIDADE FORNECEDOR  \
# 8                   20                      46        Baixa   Editorar
# 7                   22                      46        Baixa   Editorar
# 6                   23                      46        Baixa   Editorar
# 21                  24                      48        Baixa   Editorar
# 5                   26                      48        Baixa   Editorar
# 15                  28                      48        Baixa   Editorar
# 20                  29                      48        Baixa   Editorar
# 3                   30                      48        Baixa   Editorar
# 19                  30                      48        Baixa   Editorar
# 16                  30                      48        Baixa   Editorar
# 1                   34                      48        Baixa   Editorar
# 11                  38                      68         Alta   Editorar
# 2                   44                      48        Baixa   Editorar
# 13                  45                      70         Alta   Editorar
# 12                  48                      75         Alta   Editorar
# 0                   64                      90         Alta   Editorar
# 4                   68                      98         Alta   Editorar
# 10                  75                     110         Alta   Editorar
# 14                  81                     114         Alta   Editorar
# 9                  142                     198         Alta   Editorar
# 18                 373                     420         Alta   Editorar
# 17                 424                     460         Alta   Editorar
#
#     Nº DA PLANILHA STATUS DE PGTO
# 8           235882      Empenhado
# 7           235883      Empenhado
# 6           235881      Empenhado
# 21          236025      Empenhado
# 5           235880      Empenhado
# 15          235981      Empenhado
# 20          236021      Empenhado
# 3           235876      Empenhado
# 19          235983      Empenhado
# 16          235984      Empenhado
# 1           235832      Empenhado
# 11          235909      Empenhado
# 2           235874      Empenhado
# 13          235979      Empenhado
# 12          235964      Empenhado
# 0           235806      Empenhado
# 4           235878      Empenhado
# 10          235905      Empenhado
# 14          235980      Empenhado
# 9           235798      Empenhado
# 18          235986      Empenhado
# 17          235985      Empenhado

# %%
# verifiacando valores nulos
excelFile2.isnull().sum()
# Out:
# ENTIDADE                  0
# PUBLICAÇÃO                0
# Nº de páginas WORD        0
# Nº de páginas estimado    0
# COMPLEXIDADE              0
# FORNECEDOR                0
# Nº DA PLANILHA            0
# STATUS DE PGTO            0
# dtype: int64

# %%
# retirar registro nulos
excelFile2=excelFile2.dropna()

# %%
# verifiacando valores nulos
excelFile2.isnull().sum()
# Out:
# ENTIDADE                  0
# PUBLICAÇÃO                0
# Nº de páginas WORD        0
# Nº de páginas estimado    0
# COMPLEXIDADE              0
# FORNECEDOR                0
# Nº DA PLANILHA            0
# STATUS DE PGTO            0
# dtype: int64

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                  object
# PUBLICAÇÃO                object
# Nº de páginas WORD         int64
# Nº de páginas estimado     int64
# COMPLEXIDADE              object
# FORNECEDOR                object
# Nº DA PLANILHA             int64
# STATUS DE PGTO            object
# dtype: object

# %%
import numpy as np
excelFile2["Nº DA PLANILHA"] = (pd.to_numeric(excelFile2["Nº DA PLANILHA"], errors='coerce').fillna(0).astype(np.int64))#,downcast='integer'))
#excelFile2["Nº DA PLANILHA"] = excelFile2["Nº DA PLANILHA"].astype('int64',errors='ignore')

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                  object
# PUBLICAÇÃO                object
# Nº de páginas WORD         int64
# Nº de páginas estimado     int64
# COMPLEXIDADE              object
# FORNECEDOR                object
# Nº DA PLANILHA             int64
# STATUS DE PGTO            object
# dtype: object

# %%
df.dtypes
# Out:
# Nº DA PLANILHA             int64
# Qtd_PG_word               object
# Qtd_carac                  int64
# Qtd_tabela                 int64
# Qtd_image                  int64
# Qtd_estilos                int64
# Data              datetime64[ns]
# dtype: object

# %%
excelFile2
# Out:
#    ENTIDADE                                         PUBLICAÇÃO  \
# 0       CNI  Mecanismo de desenvolvimento sustentável e com...
# 1       CNI  A difusão das tecnologias da indústria 4.0 em ...
# 2       CNI                           Financiamento para Clima
# 3       CNI                                 Agenda for Germany
# 4       CNI                   Estudo sobre o impacto econômico
# 5       CNI                               Agenda para o México
# 6       CNI                          Agenda para o Reino Unido
# 7       CNI                               Agenda para a França
# 8       CNI                          Agenda para Coreia do Sul
# 9       CNI                                Mineração no Brasil
# 10      CNI  Proposta de regime para desonerar as importações
# 11      CNI                                         Nova Camex
# 12      CNI                     Teletrabalho no Brasil e mundo
# 13     SESI                           Educação Infantil 3 anos
# 14     SESI                       Educação Infantil 4 e 5 anos
# 15     SESI                                  EJA - Anos Finais
# 16     SESI                                 EJA - Ensino Médio
# 17     SESI                   Ensino Fundamental - Anos Finais
# 18     SESI                 Ensino Fundamental - Anos Iniciais
# 19     SESI                                EJA - Anos Iniciais
# 20      CNI                                   Agenda for Japan
# 21     SESI                 Fortalecimento da defesa comercial
#
#     Nº de páginas WORD  Nº de páginas estimado COMPLEXIDADE FORNECEDOR  \
# 0                   64                      90         Alta   Editorar
# 1                   34                      48        Baixa   Editorar
# 2                   44                      48        Baixa   Editorar
# 3                   30                      48        Baixa   Editorar
# 4                   68                      98         Alta   Editorar
# 5                   26                      48        Baixa   Editorar
# 6                   23                      46        Baixa   Editorar
# 7                   22                      46        Baixa   Editorar
# 8                   20                      46        Baixa   Editorar
# 9                  142                     198         Alta   Editorar
# 10                  75                     110         Alta   Editorar
# 11                  38                      68         Alta   Editorar
# 12                  48                      75         Alta   Editorar
# 13                  45                      70         Alta   Editorar
# 14                  81                     114         Alta   Editorar
# 15                  28                      48        Baixa   Editorar
# 16                  30                      48        Baixa   Editorar
# 17                 424                     460         Alta   Editorar
# 18                 373                     420         Alta   Editorar
# 19                  30                      48        Baixa   Editorar
# 20                  29                      48        Baixa   Editorar
# 21                  24                      48        Baixa   Editorar
#
#     Nº DA PLANILHA STATUS DE PGTO
# 0           235806      Empenhado
# 1           235832      Empenhado
# 2           235874      Empenhado
# 3           235876      Empenhado
# 4           235878      Empenhado
# 5           235880      Empenhado
# 6           235881      Empenhado
# 7           235883      Empenhado
# 8           235882      Empenhado
# 9           235798      Empenhado
# 10          235905      Empenhado
# 11          235909      Empenhado
# 12          235964      Empenhado
# 13          235979      Empenhado
# 14          235980      Empenhado
# 15          235981      Empenhado
# 16          235984      Empenhado
# 17          235985      Empenhado
# 18          235986      Empenhado
# 19          235983      Empenhado
# 20          236021      Empenhado
# 21          236025      Empenhado

# %%
# QUANTIDAD DE LINHAS DO ARQUIVO EXCEL PODE DIFERENCIAL DA QUANTIDADE DE LINHAS DO DF (LEITURA DOS ARQUIVOS WORD) 
# PORQUE ALGUNS ARQUIVOS DO WORD NÃO SÃO COM EXTENSÃO .DOCX , OU SEJA O PROGRAMA NÃO TRATA ARQUIVOS .DOC

# %%
df
# Out:
#     Nº DA PLANILHA Qtd_PG_word  Qtd_carac  Qtd_tabela  Qtd_image  Qtd_estilos  \
# 0           235880          26      17783           3          2           23
# 1           235980          11     163469          12         65           15
# 2           235985         424     660609         107         75           27
# 3           235905          75      97635         126         94           54
# 4           235909          38      75538         131         98           21
# 5           235876          30      23238         133        107           29
# 6           235798         142     247205         154        130           26
# 7           235986         374     586948         256        138           21
# 8           235882          20      12344         258        140           25
# 9           235881          23      14560         260        142           28
# 10          235964          48      72824         262        144           16
# 11          235878           1      87223         275        156          127
# 12          235883          22      14344         277        158           29
# 13          236021          29      22781         279        160           20
# 14          235979          45      72613         286        207           15
# 15          235832          34      70983         288        211           16
# 16          236025          24      33141         293        216           19
#
#          Data
# 0  2020-08-26
# 1  2020-09-14
# 2  2020-09-16
# 3  2020-08-31
# 4  2020-09-02
# 5  2020-08-21
# 6  2020-08-20
# 7  2020-09-16
# 8  2020-08-26
# 9  2020-08-26
# 10 2020-09-04
# 11 2020-08-17
# 12 2020-08-26
# 13 2020-09-19
# 14 2020-09-14
# 15 2020-08-07
# 16 2020-09-16

# %%
# unir arquivo do NGE com o método de leitura dos arquivos Word
#
# Atenção >>>>>>>> alguns arquivos não passaram pelo método de leitura dos arquivos word e irão gerar valores NAN
#
df_final = pd.merge(excelFile2, df, on=['Nº DA PLANILHA'], how='left')

# %%
# colocando ordem das colunas adequada
excelFile2.columns
#colunas_final = ['Nº DA PLANILHA','ENTIDADE',  'FORNECEDOR','COMPLEXIDADE', 'STATUS DE PGTO',  'Nº de páginas WORD','Nº de páginas estimado', 'Qtd_carac','Qtd_tabela', 'Qtd_image','Nº de páginas finais' ]
colunas_final = ['Nº DA PLANILHA','ENTIDADE',  'FORNECEDOR','COMPLEXIDADE', 'STATUS DE PGTO',  'Nº de páginas WORD','Nº de páginas estimado', "Qtd_PG_word",'Qtd_carac','Qtd_tabela', 'Qtd_image',"Qtd_estilos"]
df_final = df_final[colunas_final]

# %%
# -----> verificar valores NAN 
df_final.isnull().sum()
# OS REGISTROS COM NAN NESSE CASO FORAM OS ARQUIVOS WORD QUE NÃO FOI ENCONTRADO.
# Out:
# Nº DA PLANILHA            0
# ENTIDADE                  0
# FORNECEDOR                0
# COMPLEXIDADE              0
# STATUS DE PGTO            0
# Nº de páginas WORD        0
# Nº de páginas estimado    0
# Qtd_PG_word               5
# Qtd_carac                 5
# Qtd_tabela                5
# Qtd_image                 5
# Qtd_estilos               5
# dtype: int64

# %%
# retirar registro nulos
df_final=df_final.dropna()
# APAGOU AS LINHAS COM NAN

# %%
# -----> verificar valores NAN 
df_final.isnull().sum()
# Out:
# Nº DA PLANILHA            0
# ENTIDADE                  0
# FORNECEDOR                0
# COMPLEXIDADE              0
# STATUS DE PGTO            0
# Nº de páginas WORD        0
# Nº de páginas estimado    0
# Qtd_PG_word               0
# Qtd_carac                 0
# Qtd_tabela                0
# Qtd_image                 0
# Qtd_estilos               0
# dtype: int64

# %%
df_final
# Out:
#     Nº DA PLANILHA ENTIDADE FORNECEDOR COMPLEXIDADE STATUS DE PGTO  \
# 1           235832      CNI   Editorar        Baixa      Empenhado
# 3           235876      CNI   Editorar        Baixa      Empenhado
# 4           235878      CNI   Editorar         Alta      Empenhado
# 5           235880      CNI   Editorar        Baixa      Empenhado
# 6           235881      CNI   Editorar        Baixa      Empenhado
# 7           235883      CNI   Editorar        Baixa      Empenhado
# 8           235882      CNI   Editorar        Baixa      Empenhado
# 9           235798      CNI   Editorar         Alta      Empenhado
# 10          235905      CNI   Editorar         Alta      Empenhado
# 11          235909      CNI   Editorar         Alta      Empenhado
# 12          235964      CNI   Editorar         Alta      Empenhado
# 13          235979     SESI   Editorar         Alta      Empenhado
# 14          235980     SESI   Editorar         Alta      Empenhado
# 17          235985     SESI   Editorar         Alta      Empenhado
# 18          235986     SESI   Editorar         Alta      Empenhado
# 20          236021      CNI   Editorar        Baixa      Empenhado
# 21          236025     SESI   Editorar        Baixa      Empenhado
#
#     Nº de páginas WORD  Nº de páginas estimado Qtd_PG_word  Qtd_carac  \
# 1                   34                      48          34    70983.0
# 3                   30                      48          30    23238.0
# 4                   68                      98           1    87223.0
# 5                   26                      48          26    17783.0
# 6                   23                      46          23    14560.0
# 7                   22                      46          22    14344.0
# 8                   20                      46          20    12344.0
# 9                  142                     198         142   247205.0
# 10                  75                     110          75    97635.0
# 11                  38                      68          38    75538.0
# 12                  48                      75          48    72824.0
# 13                  45                      70          45    72613.0
# 14                  81                     114          11   163469.0
# 17                 424                     460         424   660609.0
# 18                 373                     420         374   586948.0
# 20                  29                      48          29    22781.0
# 21                  24                      48          24    33141.0
#
#     Qtd_tabela  Qtd_image  Qtd_estilos
# 1        288.0      211.0         16.0
# 3        133.0      107.0         29.0
# 4        275.0      156.0        127.0
# 5          3.0        2.0         23.0
# 6        260.0      142.0         28.0
# 7        277.0      158.0         29.0
# 8        258.0      140.0         25.0
# 9        154.0      130.0         26.0
# 10       126.0       94.0         54.0
# 11       131.0       98.0         21.0
# 12       262.0      144.0         16.0
# 13       286.0      207.0         15.0
# 14        12.0       65.0         15.0
# 17       107.0       75.0         27.0
# 18       256.0      138.0         21.0
# 20       279.0      160.0         20.0
# 21       293.0      216.0         19.0

# %%
# reindexar o index devido ter deletado algumas linhas
df_final.reset_index(drop=True, inplace=True)

# %%
df_final.dtypes
# Out:
# Nº DA PLANILHA              int64
# ENTIDADE                   object
# FORNECEDOR                 object
# COMPLEXIDADE               object
# STATUS DE PGTO             object
# Nº de páginas WORD          int64
# Nº de páginas estimado      int64
# Qtd_PG_word                object
# Qtd_carac                 float64
# Qtd_tabela                float64
# Qtd_image                 float64
# Qtd_estilos               float64
# dtype: object

# %%
df_final.head()
# Out:
#    Nº DA PLANILHA ENTIDADE FORNECEDOR COMPLEXIDADE STATUS DE PGTO  \
# 0          235832      CNI   Editorar        Baixa      Empenhado
# 1          235876      CNI   Editorar        Baixa      Empenhado
# 2          235878      CNI   Editorar         Alta      Empenhado
# 3          235880      CNI   Editorar        Baixa      Empenhado
# 4          235881      CNI   Editorar        Baixa      Empenhado
#
#    Nº de páginas WORD  Nº de páginas estimado Qtd_PG_word  Qtd_carac  \
# 0                  34                      48          34    70983.0
# 1                  30                      48          30    23238.0
# 2                  68                      98           1    87223.0
# 3                  26                      48          26    17783.0
# 4                  23                      46          23    14560.0
#
#    Qtd_tabela  Qtd_image  Qtd_estilos
# 0       288.0      211.0         16.0
# 1       133.0      107.0         29.0
# 2       275.0      156.0        127.0
# 3         3.0        2.0         23.0
# 4       260.0      142.0         28.0

# %%
# alterar campos typo string para categóricos 
df_final['ENTIDADE'] = df_final['ENTIDADE'].astype('category')
df_final['COMPLEXIDADE'] = df_final['COMPLEXIDADE'].astype('category')
df_final['FORNECEDOR'] = df_final['FORNECEDOR'].astype('category')
df_final['STATUS DE PGTO'] = df_final['STATUS DE PGTO'].astype('category')

# %%
# alterar campos typo categóricos para numérico
# aplicando .cat.codes em cada uma dessas colunas
df_final['ENTIDADE'] = df_final['ENTIDADE'].cat.codes
df_final['COMPLEXIDADE'] = df_final['COMPLEXIDADE'].cat.codes
df_final['FORNECEDOR'] = df_final['FORNECEDOR'].cat.codes
df_final['STATUS DE PGTO'] = df_final['STATUS DE PGTO'].cat.codes

# %%
df_final['Nº de páginas WORD'] = df_final['Nº de páginas WORD'].astype('int')

# %%
# Verificar se tem alguma inconsistencia na planilha Excel - Quantidade de páginas por exemplo
df_final.sort_values('Nº de páginas WORD')

# eliminar linhas com menos de 10 páginas
filtro  = df_final['Nº de páginas WORD'] > 10
df_final = df_final[filtro]

# %%
df_final.dtypes
# Out:
# Nº DA PLANILHA              int64
# ENTIDADE                     int8
# FORNECEDOR                   int8
# COMPLEXIDADE                 int8
# STATUS DE PGTO               int8
# Nº de páginas WORD          int64
# Nº de páginas estimado      int64
# Qtd_PG_word                object
# Qtd_carac                 float64
# Qtd_tabela                float64
# Qtd_image                 float64
# Qtd_estilos               float64
# dtype: object

# %%
df_final.head()
# Out:
#    Nº DA PLANILHA  ENTIDADE  FORNECEDOR  COMPLEXIDADE  STATUS DE PGTO  \
# 0          235832         0           0             1               0
# 1          235876         0           0             1               0
# 2          235878         0           0             0               0
# 3          235880         0           0             1               0
# 4          235881         0           0             1               0
#
#    Nº de páginas WORD  Nº de páginas estimado Qtd_PG_word  Qtd_carac  \
# 0                  34                      48          34    70983.0
# 1                  30                      48          30    23238.0
# 2                  68                      98           1    87223.0
# 3                  26                      48          26    17783.0
# 4                  23                      46          23    14560.0
#
#    Qtd_tabela  Qtd_image  Qtd_estilos
# 0       288.0      211.0         16.0
# 1       133.0      107.0         29.0
# 2       275.0      156.0        127.0
# 3         3.0        2.0         23.0
# 4       260.0      142.0         28.0

# %%
df_final.columns
# Out:
# Index(['Nº DA PLANILHA', 'ENTIDADE', 'FORNECEDOR', 'COMPLEXIDADE',
#        'STATUS DE PGTO', 'Nº de páginas WORD', 'Nº de páginas estimado',
#        'Qtd_PG_word', 'Qtd_carac', 'Qtd_tabela', 'Qtd_image', 'Qtd_estilos'],
#       dtype='object')

# %%
# trocar type float por int
df_final["Qtd_PG_word"] = df_final["Qtd_PG_word"].astype('int')
df_final['Qtd_carac'] = df_final['Qtd_carac'].astype('int')
df_final['Qtd_tabela'] = df_final['Qtd_tabela'].astype('int')
df_final['Qtd_image'] = df_final['Qtd_image'].astype('int')

# %%
df_final.columns
# Out:
# Index(['Nº DA PLANILHA', 'ENTIDADE', 'FORNECEDOR', 'COMPLEXIDADE',
#        'STATUS DE PGTO', 'Nº de páginas WORD', 'Nº de páginas estimado',
#        'Qtd_PG_word', 'Qtd_carac', 'Qtd_tabela', 'Qtd_image', 'Qtd_estilos'],
#       dtype='object')

# %%
df_final.dtypes
# Out:
# Nº DA PLANILHA              int64
# ENTIDADE                     int8
# FORNECEDOR                   int8
# COMPLEXIDADE                 int8
# STATUS DE PGTO               int8
# Nº de páginas WORD          int64
# Nº de páginas estimado      int64
# Qtd_PG_word                 int64
# Qtd_carac                   int64
# Qtd_tabela                  int64
# Qtd_image                   int64
# Qtd_estilos               float64
# dtype: object

# %%
#renomear colunas

#df_final.rename(columns={'Nº DA PLANILHA': 'id','ENTIDADE':"entidade",'FORNECEDOR':"fornecedor", 'COMPLEXIDADE':"complexidade",
#                         'STATUS DE PGTO':"stat_pagto",'Nº de páginas WORD':"qtd_pag_word", 
#                         'Nº de páginas estimado':"qtd_pag_estimado", 'Qtd_carac':"qtd_carc",
#       'Qtd_tabela':"qtd_tabela", 'Qtd_image': "qtd_image", 'Nº de páginas finais':"pag_final"} , inplace = True)

df_final.rename(columns={'Nº DA PLANILHA': 'id','ENTIDADE':"entidade",'FORNECEDOR':"fornecedor", 'COMPLEXIDADE':"complexidade",
                         'STATUS DE PGTO':"stat_pagto",'Nº de páginas WORD':"qtd_pag_word", 
                         'Nº de páginas estimado':"qtd_pag_estimado", "Qtd_PG_word":"qtd_pg_word",'Qtd_carac':"qtd_carc",
       'Qtd_tabela':"qtd_tabela", 'Qtd_image': "qtd_image","Qtd_estilos":"qtd_estilos"} , inplace = True)

# %%
# gerar arquivo csv para arquivo tratado

df_final.to_csv("nge_dados_input_semNF.csv",index=False )

#data = pd.read_csv("nge_dados_input.csv")
#df_final.to_csv(index=False)
#df_final.to_csv("nge_dados_input.csv", data = imprimir_ano)

# %%
#df_final.columns

# %%
#colunas_X= ['complexidade', 'qtd_pag_word', 'qtd_carc','qtd_tabela','qtd_image',"qtd_estilos",'qtd_carc_normal']
