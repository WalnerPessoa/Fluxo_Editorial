# %%
# orientaçÕes para instalar sdk da AZURE
# https://docs.microsoft.com/en-us/python/api/overview/azure/ml/install?view=azure-ml-py

# %%
# !pip3 install azureml-sdk
# Out:
# ...
#      |████████████████████████████████| 101 kB 966 kB/s ta 0:00:01
# ...
#      |████████████████████████████████| 2.0 MB 8.2 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 8.6 MB 2.0 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 177 kB 1.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 28.2 MB 80 kB/s  eta 0:00:01
# ...
#      |████████████████████████████████| 11.0 MB 174 kB/s eta 0:00:01
# ...
#      |████████████████████████████████| 718 kB 6.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 89 kB 4.6 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 84 kB 1.0 MB/s eta 0:00:011
# ...
#      |████████████████████████████████| 968 kB 5.5 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 40 kB 586 kB/s eta 0:00:011
# ...
#      |████████████████████████████████| 145 kB 5.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 141 kB 6.4 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 547 kB 6.0 MB/s eta 0:00:01
# ...

# %%
# !pip3 install azureml-core

# %%
# !pip3 show azureml-core
# Out:
# Name: azureml-core
# Version: 1.16.0.post1
# Summary: Azure Machine Learning core packages, modules, and classes
# Home-page: https://docs.microsoft.com/python/api/overview/azure/ml/?view=azure-ml-py
# Author: Microsoft Corp
# Author-email: None
# License: https://aka.ms/azureml-sdk-license
# Location: /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages
# Requires: PyJWT, jmespath, azure-graphrbac, pathspec, pyopenssl, msrestazure, backports.tempfile, azure-mgmt-containerregistry, docker, pytz, adal, azure-mgmt-storage, azure-common, jsonpickle, msrest, cryptography, ndg-httpsclient, contextlib2, ruamel.yaml, azure-mgmt-keyvault, azure-mgmt-resource, azure-mgmt-authorization, python-dateutil, SecretStorage, requests, urllib3
# Required-by: azureml-train-core, azureml-train-automl-client, azureml-telemetry, azureml-sdk, azureml-pipeline-core

# %%
# !pip3 install --upgrade --upgrade-strategy eager azureml-sdk
# Out:
# Requirement already up-to-date: azureml-sdk in /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages (1.16.0)
# Requirement already up-to-date: azureml-dataset-runtime[fuse]~=1.16.0 in /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages (from azureml-sdk) (1.16.0)
# Requirement already up-to-date: azureml-train-automl-client~=1.16.0 in /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages (from azureml-sdk) (1.16.0)
# Requirement already up-to-date: azureml-core~=1.16.0 in /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages (from azureml-sdk) (1.16.0.post1)
# Requirement already up-to-date: azureml-pipeline~=1.16.0 in /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages (from azureml-sdk) (1.16.0)
# Requirement already up-to-date: azureml-train~=1.16.0 in /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages (from azureml-sdk) (1.16.0)
# ...

# %%
#from azureml import Workspace
from azureml.core import Workspace
#from azureml.core.webservice import Webservice

ws = Workspace(
    workspace_id='b61d12027ff74d329be4643248e190ae',
    authorization_token='Ci7C5j8Dod+7tQs0ds7cgE+RL7oJO4ZbifWQcZCWgODn/UNVGLfqKAy8WoQF6lDWjeP9Ynvw4oFIFdUnCFLyUw==',
    endpoint='https://studioapi.azureml.net'
)
ds = ws.datasets['Automobile price data (Raw)']
frame = ds.to_dataframe()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-402659a62bba> in <module>
#       3 #from azureml.core.webservice import Webservice
#       4
# ----> 5 ws = Workspace(
#       6     workspace_id='b61d12027ff74d329be4643248e190ae',
#       7     authorization_token='Ci7C5j8Dod+7tQs0ds7cgE+RL7oJO4ZbifWQcZCWgODn/UNVGLfqKAy8WoQF6lDWjeP9Ynvw4oFIFdUnCFLyUw==',
#
# TypeError: __init__() got an unexpected keyword argument 'workspace_id'
