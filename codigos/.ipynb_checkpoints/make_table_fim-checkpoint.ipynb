# %%
# metodo de tratar tabelas

# %%
import os
import get_file_word_fim as gf
import datetime
import pandas as pd

#setar variáveis onde estão arquivos
fileExt = r".docx"
fileExt2 = r".doc"
fileDir_19 = r"/Users/wpessoa/repositorios/NGE/words_2019/"
fileDir_20 = r"/Users/wpessoa/repositorios/NGE/words_2020/"


fileDir_semNF = r"/Users/wpessoa/repositorios/NGE/words_semNota/"

# verificar se existe o diretório
print("Existe esse diretório? ",os.path.exists(fileDir_19)) 
print("Existe esse diretório? ",os.path.exists(fileDir_20)) 


#fileDir = r"/Users/wpessoa/repositorios/Fluxo_Editorial/words/"
#fileDir= r'/Users/walnerpessoa/repositories/Fluxo_Editorial/words'
files_array_19 = [_ for _ in os.listdir(fileDir_19) if _.endswith(fileExt)]
#files_array_19_2 = [_ for _ in os.listdir(fileDir_19) if _.endswith(fileExt2)]
#files_array_19=files_array_19_1+files_array_19_2


files_array_20 = [_ for _ in os.listdir(fileDir_20) if _.endswith(fileExt)]
#files_array_20_2 = [_ for _ in os.listdir(fileDir_20) if _.endswith(fileExt2)]
#files_array_20=files_array_20_1+files_array_20_2

print("Quantidade de arquivos do word no diretório: ",len(files_array_19))
print("Quantidade de arquivos do word no diretório: ",len(files_array_20))



# rodar método get_info para ler aquivos do Word e retornar features de cada arquivo
# argumentos (diretório e array dos arquivos word)
# retorna (NºID,Qtd_caracteres,Qtd_tabela,Qtd_image,data)

var_19=gf.get_info(fileDir_19,files_array_19)
var_20=gf.get_info(fileDir_20,files_array_20)

#print(var)

#Quantidade de arquivos do word no diretório:  58
# Quantidade de arquivos do word no diretório:  52

#Quantidade de arquivos do word no diretório:  56
#Quantidade de arquivos do word no diretório:  50
# Out:
# Existe esse diretório?  True
# Existe esse diretório?  True
# Quantidade de arquivos do word no diretório:  60
# Quantidade de arquivos do word no diretório:  80
# ID228354-CNI_ Estudo Mecanismo de Soluá∆o de Consulta Antecipada_vf+RevisaoGramatical.docx
# ID235502-Investimentos_Roadmap_BrasilUK_v5_Normalizado.docx
# ID232098-2019-09-16_30 CASOS_FINAL 20190820 (inglês).docx
# ID225392-Manual Ouvidoria do SESI SENAI REVISADO POR DANUZIA - NORMALIZADOv2 - 06.11.18.docx
# ID228307-Pesquisa Sindical 2018_Relatório_versão final.docx
# ID224325-Reuso_PE-normalizado_revisado_final.docx
# ID232211-Agendar for USA.docx
# ID230571-10 Chamada_20190619 - - (1).docx
# ID229536-Avanços da Gestão SESI-SENAI-IEL v10.docx
# ID231772-Versão preliminar I-2027 MPE-2.docx
# ID226842-20190115 Estudo_ApoioExportadorDefesaComercial_v08.docx
# ID231928-Investimentos_Tributação_Roadmap_BrasilEUA_20190328_Normalizado_06092019_123259.docx
# ID233550-2019-11-25_CNI Agências Reguladoras Subnacionais- v2 - normalização concluída.docx
# ID228603-Posicao Mercosul PPT Argentina_v11.docx
# ID228863-2019-03-25 _TratamentodaChinaComoEconomiadeMercado_NME_v04.docx
# ID231316-Mexico_InteressesOfensivos_201907_Normalizado_v02.docx
# ID229294 -Normatizado  Livro ESocial - empregado ajustado depois da DJ_revisado empresa externa.docx
# ID231829-2019-08-20 Estudo_CustosAeroportuarios_Relatorio_v15_normalizado.docx
# ID230908-2019-07-04 Alemanha_2019_v4.docx
# ID231210-2019-09-06 NR 12 - Comentarios ao novo texto geral. edição para diagramação.docx
# ID229323-Normatizado  Livro ESocial - empregado ajustado depois da DJ_revisado empresa externa.docx
# ID000003-Estudo temático_Impactos da revolução digital Unesco_Unificado_19ago2019.docx
# ID228837-Mercosul_Alteracao Tarifaria_201902_v09_Normalizado (1).docx
# ID228437-Recuperacao_Energetica_normalizado_revisado.docx
# ID230630-2019-06-24_Reuso PB_normalizada_V02.docx
# ID233405-2019-11-14 1128 Cartilha licenciamento ambiental_V9_normalizado_revisado_14112019_180959.docx
# ID233069-AgendaPara_MÇxico_2019.docx
# ID233474-Ecommerce_ResultadosConsulta_v06_Normalizado.docx
# ID000000-Manual de formatos - Oficial.docx
# ID231055-AgendaPara_EstadosUnidos_2019 (1).docx
# ID232596-CNI_DocumentodePosicao_Brexit_v11_Normalizado.docx
# ID225531-Versão Revisada e Normalizada_FINAL.docx
# ID230301-2019.06.05_reuso rj_V03.docx
# ID233269-19.11 Relatorio Executivo FINAL_Normalizado.docx
# ID228711-RELAToRIO SESI SENAI IEL 2018_PRELIMINAR_NORMALIZADO_2019.03.14.docx
# ID231931-2019-08-26 Posiá∆o CNI_Reforma da OMC_v06_20190808_normalizado.docx
# ID232943-CNI_FC_Estudo_FacilitacaoComercioMercosul_vlimpa_normalizada REVISADO_rp FINAL (2).docx
# ID231201-2019-07-23_30 CASOS_FINAL REVISADO NORMALIZAÇÃO.docx
# ID229345-OECD_CompatibilidadeSistemaBrasileiro_v08_Normalizado.docx
# ID230277-19.05 Estudo final Esp gás_Nornalizado_Rev J (2).docx
# ID231274-Versão Preliminar do Plano Estratégico_v10_enviado para Diret.docx
# ID229428-Doc de Política Industrial Revisado - 02-04-2019_02052019_145149.docx
# ID230874-Estudo_ProdutividadedasMultis_Normalizado.docx
# ID232396-FinanciamentoeGarantias_BenchmarkingInternacional_v08_Normalizado.docx
# ID232174-2019-08-23 AgendaPara_Japao_2019.docx
# ID231938-AgendaPara_Alemanha_2019_Mark.docx
# ID22703-FINAL_Agenda Jurídica da Indústria 2019 - STF (ÁBARIS)_31012019_145404.docx
# ID230059-CNI_ConselhosUsuarios_Completa_20190510_vnormalizada-revisada (1).docx
# ID225392-CNI_Atos Internacionais_201810_normalizado_final.docx
# ID231431-Re£so ES_nor_rev.docx
# ID224323-Reuso_CE-normalizado_revisado_final.docx
# ID233263-2019-11-05 Boas praticas de parceria_Versao consolidada3_para editoração.docx
# ID230385-Investimentos_ManualdeAcordosPrevidenci rio_v6_Normalizado.docx
# ID232625-Guia do Docente_Editorado.docx
# ID231890-Posicionamento sobre licenciamento ambiental VFinal.docx
# ID232393-Guia Avaliação última versão v 02_10_2019 _ Normalizado (1).docx
# ID231637-2019-08-09 CNI_CAM_Avancos&ImpactosParaBrasil_EstudoNormativoAduaneiro_20190718_v01r_limpa_ REVISADO.docx
# ID233072-2019-10-22 AgendaPara_Argentina_2019.docx
# ID232872-CNI_FC_GestaoRiscoOrgaosAnuentesComercioExterior_Estudo_vf.docx
# ID227130-2019-01-18_Guia de Financiamento Climático_vs final (2).docx
# ID235651-2020-06-16 AgendaPara_BRICS_2020_Normalizada (1).docx
# ID236123-Carta_presidente_20201002_MC Precificação de Carbono  e Competitividade da Indústria_v01_atualizada (1).docx
# ID235534-2020-06-02 AgendaPara_Japao_2020_Normalizada (3).docx
# ID235502-Investimentos_Roadmap_BrasilUK_v5_Normalizado.docx
# ID235880-AgendaPara_MÇxico_2020_Normalizada (1).docx
# ID235665-Normas e Politicas de Uso_Revisado DJ_FINAL.docx
# ID233694-Relatório Diretoria Jurídica 2018-1 - Cópia (1).docx
# ID233896-2020-01-29 AII2020_Consolidação_V10.docx
# ID235810-AgendaPara_China_Normalizada (1).docx
# ID233899-Caderno de ações e resultados 2019 - Versão Editoração .docx
# ID235305-Mercosul_ImpactosJuridicosSaidaBrasil_RelatorioCompleto_202003_v03_Normalizado (1).docx
# ID233903-2020-05-02 Tradução Relatórios EUA e UE Distorções China_2020_v02 REVISADO_NORMALIZADO_sem comentários.docx
# ID235520-2020-05-25 AgendaPara_Alemanha_2020_Normalizada (1).docx
# ID235980-Educação Infantil  4 e 5  anos - Diagramar.docx
# ID235512-2020-06-05 OCDE_EstudoConvergênciaInstrumentosMeioAmbiente_v10_normalizado (1).docx
# ID233904-2020-03-06 Estudo CNI_ China  Subsídios chineses identificados em investigações sobre medidas compensatórias no mundo(459760.20) (003)_Normalizado.docx
# ID235513-2020-05-14 GUIA_PPN-Corrigido_Final_normalizado REVISADO-Comentado (1).docx
# ID235664-Governança de Dados_Revisado DJ_FINAL.docx
# ID235511-2020-05-29 AgendaParaEUA_2020_normalizado.docx
# ID235509-Investimentos_Estudo_Compatibilidade da cláusula de arbitragem com os ADTs celebrados pelo Brasil_Normalizado.docx
# ID235142-2020-03-30 0922 Bioeconomia e a Indústria Brasileira_30-03-2020_normalizado_vf.docx
# ID233900-Relatório Atividades 2019_SESI-SENAI-IEL_versão preliminar.docx
# ID235985-EF ANOS FINAIS CONSOLIDADO.docx
# ID233892-8- Templates.docx
# ID235382-2020-05-20-1 Manual de eventos.docx
# ID236105-2020-09-23 Estudo_NormasLegais_CNI_vers∆o_revisada_set2020 (1).docx
# ID233909-2020-03-11 publicacao_caminho_estrategico_economia_circular (ingl.)_normalizado.docx
# ID233867-06_12_2019_EFEITOS DA GESTÃO SOBRE A PRODUTIVIDADE - PARA PUBLICAÇÃO_Final_19122019_155125.docx
# ID233884-Agenda Jurídica STF 2020 (versão PRELIMINAR).docx
# ID235701-08-07-2020 2º GUIA - Tempo de Ensinar e Aprender Final - Validado e Revisado (1).docx
# ID235650-2020-06-05 AgendaPara_Argentina_2020_Normalizada (1).docx
# ID235353-2020-05-06 Estudo CNI _ Documento de POsição OMC sem Órgão de Apelação.docx
# ID235313-2020-05-05 2320 CNI - Estudo - Protocolo de Nagoya - normalizado_ 06_05.docx
# ID235983-EJA - ANOS INICIAIS_Diagramar.docx
# ID233885-1- Metodol Rec Did - rev.docx
# ID233893-Códigos_EstudoCNI_v10.docx
# ID235905-EstudoRegimeEspecialServicos_NormalizacaoCompleta_20200831.docx
# ID233891-7- Guia Microlearning - rev.docx
# ID235909-CAMEX_Estudo1_consolidadoAI_normalizado.docx
# ID235700-2020-06-26 1º GUIA - TEMPO DE PLANEJAR - Validado REVISADO.docx
# ID235876-2020-05-25 AgendaPara_Alemanha_2020_Normalizada TRAD _rev.docx
# ID235812-AgendaPara_India_Normalizada (2).docx
# ID233905-Proposta da Industria 2020-2022 2020_03_04.docx
# ID235798-2020-08-20 MINERACAO NO BRASIL RUMO A UMA INDUSTRIA PRODUTIVA_ SEGURA E SUSTENTA´VEL (1).docx
# ID235986-EF ANOS INICIAIS CONSOLIDADO.docx

# %%
#files_array_19_2

# %% [markdown]
# - Existe esse diretório?  True
# - Existe esse diretório?  True
# - Quantidade de arquivos do word no diretório:  58
# - Quantidade de arquivos do word no diretório:  35

# %%
print(type(var_19))
# Out:
# <class 'list'>

# %%
# unindo lista 2019 com lista 2020
var=var_19+var_20

# %%
#df.count()

# %%
#df[df['Nº DA PLANILHA'].isnull()]

# %%
# converter veriável de retorno do método para Dataframe
#df = pd.DataFrame(var,columns=['Nº DA PLANILHA',"Qtd_carac","Qtd_tabela","Qtd_image","Data"])
df = pd.DataFrame(var,columns=['Nº DA PLANILHA',"Qtd_PG_word","Qtd_carac","Qtd_tabela","Qtd_image","Qtd_estilos", "Data"])

df.head()
# Out:
#   Nº DA PLANILHA Qtd_PG_word  Qtd_carac  Qtd_tabela  Qtd_image  Qtd_estilos  \
# 0         228354          76     129122          14         10           26
# 1         235502          24      31123          21         17           23
# 2         232098         195     413596          26         20           19
# 3         225392          30      41144          28         24           23
# 4         228307          62      43155          40         73           25
#
#          Data
# 0  2019-02-27
# 1  2020-05-27
# 2  2019-09-16
# 3  2018-11-07
# 4  2019-02-26

# %%
df
# Out:
#     Nº DA PLANILHA Qtd_PG_word  Qtd_carac  Qtd_tabela  Qtd_image  Qtd_estilos  \
# 0           228354          76     129122          14         10           26
# 1           235502          24      31123          21         17           23
# 2           232098         195     413596          26         20           19
# 3           225392          30      41144          28         24           23
# 4           228307          62      43155          40         73           25
# ..             ...         ...        ...         ...        ...          ...
# 116         235811          34      29372         562        574           18
# 117         233887          28      47904         567        579           14
# 118         235495          39      31612         577        592           25
# 119         233906          78     118624         580        661           19
# 120         236025          24      33141         585        666           19
#
#            Data
# 0    2019-02-27
# 1    2020-05-27
# 2    2019-09-16
# 3    2018-11-07
# 4    2019-02-26
# ..          ...
# 116  2020-08-03
# 117  2020-02-05
# 118  2020-05-25
# 119  2020-03-09
# 120  2020-09-16
#
# [121 rows x 7 columns]

# %%
# verificando tipo das variáveis
df.dtypes
# Out:
# Nº DA PLANILHA    object
# Qtd_PG_word       object
# Qtd_carac          int64
# Qtd_tabela         int64
# Qtd_image          int64
# Qtd_estilos        int64
# Data              object
# dtype: object

# %%
# converter tipo para inteiros e data
df["Nº DA PLANILHA"] = pd.to_numeric(df["Nº DA PLANILHA"], errors='coerce')
df["Data"] = pd.to_datetime(df["Data"])

# %%
df.dtypes
# Out:
# Nº DA PLANILHA           float64
# Qtd_PG_word               object
# Qtd_carac                  int64
# Qtd_tabela                 int64
# Qtd_image                  int64
# Qtd_estilos                int64
# Data              datetime64[ns]
# dtype: object

# %%
#Convertendo arquivo excel em dataframe

excelDir ="/Users/wpessoa/repositorios/Fluxo_Editorial/dados/"
excelFile_2019 = pd.read_excel(excelDir+'Exercicio_estimativa_de_paginas_2019_2020.xlsx',"EXECUTADO 2019")
excelFile_2020 = pd.read_excel(excelDir+'Exercicio_estimativa_de_paginas_2019_2020.xlsx',"EXECUTADO 2020")
#excelFile_2020 = pd.read_excel(excelDir+'Planilha de Acompanhamento Editoração 2020.xlsx',"ACOMPANHAMENTO", header=1)

# %%
len(excelFile_2020.columns)
# Out:
# 26

# %%
len(excelFile_2019.columns)
# Out:
# 28

# %%
excelFile_2020.columns
# Out:
# Index(['ENTIDADE', 'PUBLICAÇÃO', 'Nº de páginas WORD',
#        'Nº de páginas estimado',
#        'Variação nº de págs estimado sobre nº de págs Word', 'COMPLEXIDADE',
#        'FORNECEDOR', 'DESCRIÇÃO', 'Nº DA PLANILHA', 'CUSTO TOTAL',
#        'DATA DE ENVIO', 'DATA DE APROVAÇÃO', 'ANÁLISTA RESPONSÁVEL',
#        'SOLICITAÇÃO DE COMPRAS', 'PEDIDO DE COMPRAS', 'STATUS DE PGTO',
#        'NOTA FISCAL', 'DATA DE PGTO', 'Nº de páginas finais',
#        'Variação nº de págs do o Word sobre nº de págs finais',
#        'Variação nº de págs finais sobre nº de págs estimado', 'STATUS', 'OBS',
#        'ARQ EXTRA', 'LINHA SMARTSHEETS', 'PROJETO GRÁFICO'],
#       dtype='object')

# %%
excelFile_2020.tail(30)
# Out:
#    ENTIDADE                                         PUBLICAÇÃO  \
# 30      CNI  Análise dos impactos regulatórios da ratificaç...
# 31      CNI  Documento de referência para implantação das D...
# 32    SENAI                   Relatório de Gestão 2019 - SENAI
# 33     SESI                    Relatório de Gestão 2019 - SESI
# 34      CNI                          OMC Sem Orgão de Apelação
# 35      CNI                                            Roadmap
# 36      CNI         Pesquisa de Percepção do Corpo Diplomático
# 37      CNI  Acordo para evitar a dupla tributação entre Br...
# 38      CNI  Compatibilidade da cláusula de arbitragem com ...
# 39      CNI                         Modelos Aduaneiros Globais
# 40      CNI  A agenda ambiental e de químicos da OCDE e o B...
# 41     SESI  Relatório de Atividades 2019 - SESI / SENAI / ...
# 42      CNI                             Agenda para a Alemanha
# 43      CNI                                Agenda para o Japão
# 44      CNI                              Agenda para Argentina
# 45      CNI                        Agenda of The United States
# 46      CNI                                Agenda para o BRICS
# 47      CNI                                Governança de dados
# 48      CNI                          Normas & Políticas de uso
# 49      CNI                Bioeconomia e a Indústria (ADITIVO)
# 50      CNI                                Agenda para a China
# 51      CNI                     Agenda for the BRICS Countries
# 52      CNI                                Agenda para a Índia
# 53      CNI  Desempenho exportador das multinacionais brasi...
# 54    SENAI                        Guia MSEP - Ensino Superior
# 55    SENAI                  Guia de Operacionalização da MSEP
# 56    SENAI               MSEP / 1º Guia da Prática Pedagógica
# 57    SENAI               MSEP / 2º Guia da Prática Pedagógica
# 58    SENAI              Guia de Operalização PSAI Sustentável
# 59    SENAI            Introdução ao método do emprego apoiado
#
#     Nº de páginas WORD  Nº de páginas estimado  \
# 30                  90                     135
# 31                  49                      84
# 32                 168                     168
# 33                 162                     162
# 34                  46                      70
# 35                  40                      70
# 36                  77                     120
# 37                  24                      48
# 38                  20                      48
# 39                  59                      90
# 40                  48                      75
# 41                 100                     120
# 42                  28                      48
# 43                  29                      48
# 44                  39                      68
# 45                  42                      70
# 46                  32                      48
# 47                  40                      70
# 48                  39                      68
# 49                  73                     110
# 50                  23                      48
# 51                  34                      68
# 52                  22                      48
# 53                  28                      48
# 54                  49                      96
# 55                  56                     104
# 56                  38                      48
# 57                  33                      44
# 58                  33                      72
# 59                  12                      24
#
#     Variação nº de págs estimado sobre nº de págs Word COMPLEXIDADE  \
# 30                                           0.500000          Alta
# 31                                           0.714286          Alta
# 32                                           0.000000          Alta
# 33                                           0.000000          Alta
# 34                                           0.521739         Média
# 35                                           0.750000         Baixa
# 36                                           0.558442          Alta
# 37                                           1.000000         Baixa
# 38                                           1.400000         Baixa
# 39                                           0.525424          Alta
# 40                                           0.562500          Alta
# 41                                           0.200000          Alta
# 42                                           0.714286         Baixa
# 43                                           0.655172         Baixa
# 44                                           0.743590         Baixa
# 45                                           0.666667         Média
# 46                                           0.500000         Baixa
# 47                                           0.750000          Alta
# 48                                           0.743590          Alta
# 49                                           0.506849          Alta
# 50                                           1.086957         Baixa
# 51                                           1.000000          Alta
# 52                                           1.181818         Baixa
# 53                                           0.714286         Baixa
# 54                                           0.959184         Média
# 55                                           0.857143          Alta
# 56                                           0.263158         Baixa
# 57                                           0.333333         Baixa
# 58                                           1.181818         Baixa
# 59                                           1.000000         Baixa
#
#       FORNECEDOR                                          DESCRIÇÃO  \
# 30      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 31      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 32      Editorar  Progeto gráfico (relatório), editoração e fina...
# 33      Editorar  Progeto gráfico (relatório), editoração e fina...
# 34      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 35      Editorar  Projeto gráfico, editoração e finalização e PD...
# 36      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 37      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 38      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 39      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 40      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 41  Icomunicação            Criação de projeto gráfico e editoração
# 42      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 43      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 44      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 45      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 46      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 47      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 48      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 49      Editorar  Acréscimo de 25% sobre o valor pactuado inicia...
# 50      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 51      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 52      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 53      Editorar  Adaptação de projeto gráfico, editoração e fin...
# 54  Icomunicação  Adaptação de projeto gráfico, editoração e fin...
# 55  Icomunicação  Adaptação de projeto gráfico, editoração e fin...
# 56  Icomunicação  Adaptação de projeto gráfico, editoração e fin...
# 57  Icomunicação  Adaptação de projeto gráfico, editoração e fin...
# 58  Icomunicação  Adaptação de projeto gráfico, editoração e fin...
# 59  Icomunicação  Adaptação de projeto gráfico, editoração e fin...
#
#    Nº DA PLANILHA  CUSTO TOTAL  ... NOTA FISCAL         DATA DE PGTO  \
# 30        235313       5670.42  ...      NF 769           22/06/2020
# 31         235320     10264.50  ...      NF 779           22/07/2020
# 32              -     53631.00  ...      NF 755           22/05/2020
# 33              -     53716.50  ...      NF 756           22/05/2020
# 34         235353       507.60  ...      NF 780           22/07/2020
# 35         235469      1766.34  ...      NF 781           22/07/2020
# 36         235495      4914.50  ...      NF 782           22/07/2020
# 37         235502      1184.58  ...      NF 783           22/07/2020
# 38         235509      1184.58  ...      NF 784           22/07/2020
# 39         235519      4531.50  ...      NF 786           22/07/2020
# 40         235512      4661.25  ...      NF 785           22/07/2020
# 41         233900     10971.00  ...     NF 1305           22/05/2020
# 42         235520       999.60  ...      NF 793           22/08/2020
# 43         235534      1022.70  ...      NF 794           22/08/2020
# 44         235650      1115.10  ...      NF 795           22/08/2020
# 45         235652       507.60  ...      NF 797           22/08/2020
# 46         235651      1068.90  ...      NF 796           22/08/2020
# 47         235664       547.20  ...      NF 802  2020-09-22 00:00:00
# 48         235665      2835.00  ...      NF 801  2020-09-22 00:00:00
# 49         235142      1535.20  ...      NF 790           22/08/2020
# 50         235810       907.20  ...      NF 805  2020-09-22 00:00:00
# 51         235811      1068.90  ...      NF 803  2020-09-22 00:00:00
# 52         235812       907.20  ...      NF 804  2020-09-22 00:00:00
# 53         235831      1045.80  ...      NF 806  2020-09-22 00:00:00
# 54         235513       661.05  ...     NF 1350           22/08/2020
# 55         235514      4295.25  ...     NF 1360  2020-09-22 00:00:00
# 56         235700      1357.65  ...     NF 1361  2020-09-22 00:00:00
# 57         235701      1265.25  ...     NF 1362  2020-09-22 00:00:00
# 58         235710      1450.05  ...     NF 1365  2020-09-22 00:00:00
# 59         235813       895.65  ...     NF 1366  2020-09-22 00:00:00
#
#    Nº de páginas finais Variação nº de págs do o Word sobre nº de págs finais  \
# 30                   84                                          -0.066667
# 31                   84                                           0.714286
# 32                  168                                           0.000000
# 33                  162                                           0.000000
# 34                   54                                           0.173913
# 35                   48                                           0.200000
# 36                  100                                           0.298701
# 37                   36                                           0.500000
# 38                   36                                           0.800000
# 39                   78                                           0.322034
# 40                   66                                           0.375000
# 41                   82                                          -0.180000
# 42                   38                                           0.357143
# 43                   40                                           0.379310
# 44                   48                                           0.230769
# 45                   54                                           0.285714
# 46                   44                                           0.375000
# 47                   62                                           0.550000
# 48                   66                                           0.692308
# 49                  110                                           0.506849
# 50                   30                                           0.304348
# 51                   44                                           0.294118
# 52                   30                                           0.363636
# 53                   42                                           0.500000
# 54                   52                                           0.061224
# 55                   72                                           0.285714
# 56                   44                                           0.157895
# 57                   40                                           0.212121
# 58                   48                                           0.454545
# 59                   24                                           1.000000
#
#     Variação nº de págs finais sobre nº de págs estimado  \
# 30                                           0.377778
# 31                                           0.000000
# 32                                           0.000000
# 33                                           0.000000
# 34                                           0.228571
# 35                                           0.314286
# 36                                           0.166667
# 37                                           0.250000
# 38                                           0.250000
# 39                                           0.133333
# 40                                           0.120000
# 41                                           0.316667
# 42                                           0.208333
# 43                                           0.166667
# 44                                           0.294118
# 45                                           0.228571
# 46                                           0.083333
# 47                                           0.114286
# 48                                           0.029412
# 49                                           0.000000
# 50                                           0.375000
# 51                                           0.352941
# 52                                           0.375000
# 53                                           0.125000
# 54                                           0.458333
# 55                                           0.307692
# 56                                           0.083333
# 57                                           0.090909
# 58                                           0.333333
# 59                                           0.000000
#
#                                                STATUS             OBS  \
# 30                        Foram faturadas 84 páginas.  download feito
# 31  Planilha atualizada dia 04/06. SC antiga 04341...  download feito
# 32                       Foram faturadas 168 páginas.             NaN
# 33                       Foram faturadas 162 páginas.             NaN
# 34  Planilha atualizada. SC antiga 043626 desconsi...  download feito
# 35                        Foram faturadas 48 páginas.  download feito
# 36                       Foram faturadas 100 páginas.  download feito
# 37                        Foram faturadas 36 páginas.  download feito
# 38                        Foram faturadas 36 páginas.  download feito
# 39  Planilha não constava PDF interativo. Foram fa...  download feito
# 40                        Foram faturadas 66 páginas.  download feito
# 41                        Foram faturadas 82 páginas.  download feito
# 42                                                NaN  download feito
# 43                                                NaN  Download feito
# 44                                                NaN  DOwnload feito
# 45                                                NaN  DOwnload feito
# 46                                                NaN  DOwnload feito
# 47                                                NaN  Download feito
# 48                                                NaN  Download feito
# 49                                                NaN  DOwnload feito
# 50                                                NaN  Download feito
# 51                                                NaN  Download feito
# 52                                                NaN  Download feito
# 53                                                NaN  Download feito
# 54                                                NaN  Download feito
# 55                                                NaN  Download feito
# 56                                                NaN  Download feito
# 57                                                NaN  Download feito
# 58                                                NaN  Download feito
# 59                                                NaN  Download feito
#
#    ARQ EXTRA  LINHA SMARTSHEETS  PROJETO GRÁFICO
# 30       ZIP                 12         ESPECIAL
# 31       NaN                 12            COMUM
# 32       NaN                NaN              NaN
# 33       NaN                NaN              NaN
# 34       NaN                 12            COMUM
# 35       ZIP                 11            COMUM
# 36       ZIP                 12            COMUM
# 37       NaN                 12            COMUM
# 38       NaN                 12            COMUM
# 39       NaN                 12            COMUM
# 40       NaN                 12            COMUM
# 41       NaN                 12            COMUM
# 42       NaN                 12            COMUM
# 43       ZIP                 12            COMUM
# 44       NaN                 12            COMUM
# 45       NaN           PLANILHA            COMUM
# 46       NaN           PLANILHA            COMUM
# 47       NaN                 12            COMUM
# 48       NaN                 12            COMUM
# 49       NaN           PLANILHA            COMUM
# 50       NaN                 12            COMUM
# 51       ZIP           PLanilha            COMUM
# 52       NaN                 12            COMUM
# 53       NaN                 12            COMUM
# 54       NaN                 12            COMUM
# 55       NaN                 12            COMUM
# 56       NaN                 12            COMUM
# 57       NaN                 12            COMUM
# 58       NaN                 12            COMUM
# 59       NaN                 13            COMUM
#
# [30 rows x 26 columns]

# %%
excelFile_2019.columns
# Out:
# Index(['ENTIDADE', 'PUBLICAÇÃO', 'Nº de páginas WORD',
#        'Nº de páginas estimado',
#        'Variação nº de págs estimado sobre nº de págs Word', 'COMPLEXIDADE',
#        'FORNECEDOR', 'DESCRIÇÃO', 'Nº DA PLANILHA', 'CUSTO TOTAL',
#        'DATA DE ENVIO', 'DATA DE APROVAÇÃO', 'ANÁLISTA RESPONSÁVEL',
#        'SOLICITAÇÃO DE COMPRAS', 'PEDIDO DE COMPRAS', 'STATUS DE PGTO',
#        'NOTA FISCAL', 'DATA DE PGTO', 'Nº de páginas finais',
#        'Diferença nº de págs do Word e págs estimado',
#        'Diferença nº de págs do final e págs estimado',
#        'Variação nº de págs do o Word sobre nº de págs finais',
#        'Variação nº de págs finais sobre nº de págs estimado', 'STATUS', 'OBS',
#        'ARQ EXTRA', 'LINHA SMARTSHEETS', 'PROJETO GRÁFICO'],
#       dtype='object')

# %%
###################################################
# FAZER MERGE COM excelFile_2020 & excelFile_2019
##################################################

# %%
frames = [excelFile_2019, excelFile_2020]
excelFile2 = pd.concat(frames)

# %%
# reindexar o index devido ter deletado algumas linhas
excelFile2.reset_index(drop=True, inplace=True)

# %%
# selecionando apenas colunas necessárias
#colunas=['ENTIDADE','PUBLICAÇÃO','Nº de páginas WORD','Nº de páginas estimado', 'COMPLEXIDADE','FORNECEDOR','Nº DA PLANILHA','STATUS DE PGTO','Nº de páginas finais']
colunas=['ENTIDADE', 'PUBLICAÇÃO', 'Nº de páginas WORD',
       'Nº de páginas estimado', 'COMPLEXIDADE', 'FORNECEDOR',
       'Nº DA PLANILHA', 'STATUS DE PGTO', 'Nº de páginas finais']

excelFile2 = excelFile2[colunas]

# %%
excelFile2.columns
# Out:
# Index(['ENTIDADE', 'PUBLICAÇÃO', 'Nº de páginas WORD',
#        'Nº de páginas estimado', 'COMPLEXIDADE', 'FORNECEDOR',
#        'Nº DA PLANILHA', 'STATUS DE PGTO', 'Nº de páginas finais'],
#       dtype='object')

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                   object
# PUBLICAÇÃO                 object
# Nº de páginas WORD         object
# Nº de páginas estimado    float64
# COMPLEXIDADE               object
# FORNECEDOR                 object
# Nº DA PLANILHA             object
# STATUS DE PGTO             object
# Nº de páginas finais       object
# dtype: object

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                   object
# PUBLICAÇÃO                 object
# Nº de páginas WORD         object
# Nº de páginas estimado    float64
# COMPLEXIDADE               object
# FORNECEDOR                 object
# Nº DA PLANILHA             object
# STATUS DE PGTO             object
# Nº de páginas finais       object
# dtype: object

# %%
#excelFile2.set_index('Nº DA PLANILHA',inplace=True)

# %%
excelFile2
# Out:
#     ENTIDADE                                         PUBLICAÇÃO  \
# 0        CNI                                           Reuso CE
# 1        CNI                                           Reuso PE
# 2        CNI  Processo De Internalização Dos Atos Internacio...
# 3        CNI  Manual de orientações da ouvidoria do Sesi e d...
# 4        CNI  Guia de Propriedade Intelectual para o Jornalista
# ..       ...                                                ...
# 130    SENAI                  Guia de Operacionalização da MSEP
# 131    SENAI               MSEP / 1º Guia da Prática Pedagógica
# 132    SENAI               MSEP / 2º Guia da Prática Pedagógica
# 133    SENAI              Guia de Operalização PSAI Sustentável
# 134    SENAI            Introdução ao método do emprego apoiado
#
#     Nº de páginas WORD  Nº de páginas estimado COMPLEXIDADE    FORNECEDOR  \
# 0                   87                   140.0         Alta      Editorar
# 1                   82                   122.0         Alta      Editorar
# 2                   41                    70.0        Média      Editorar
# 3                   30                    45.0        Baixa      Editorar
# 4                   36                    48.0        Baixa      Editorar
# ..                 ...                     ...          ...           ...
# 130                 56                   104.0         Alta  Icomunicação
# 131                 38                    48.0        Baixa  Icomunicação
# 132                 33                    44.0        Baixa  Icomunicação
# 133                 33                    72.0        Baixa  Icomunicação
# 134                 12                    24.0        Baixa  Icomunicação
#
#     Nº DA PLANILHA STATUS DE PGTO Nº de páginas finais
# 0           224323           Pago                  140
# 1           224325           Pago                  122
# 2           225392           Pago                   52
# 3           225507           Pago                   32
# 4           225531           Pago                   48
# ..             ...            ...                  ...
# 130         235514           Pago                   72
# 131         235700           Pago                   44
# 132         235701           Pago                   40
# 133         235710           Pago                   48
# 134         235813           Pago                   24
#
# [135 rows x 9 columns]

# %%
excelFile2.describe()
# Out:
#        Nº de páginas estimado
# count              129.000000
# mean                93.953488
# std                 72.398297
# min                  1.000000
# 25%                 48.000000
# 50%                 75.000000
# 75%                110.000000
# max                440.000000

# %%
# Verificar se tem alguma inconsistencia na planilha Excel - Quantidade de páginas por exemplo
# excelFile2.sort_values('Nº de páginas WORD')

# %%
excelFile2['Nº de páginas finais'].unique()
# Out:
# array(['140', '122', '52', '32', '48', 88, '66', '82', '92', '70', '96',
#        '18', '40', '46', '68', '34', '28', '86', '84', '110', '116', '98',
#        '340', '72', '112', '71', '100', '43', '76', '212', '74', '38',
#        '42', '54', '104', '386', '126', '296', '196', 'RMSE', nan, 1, 52,
#        66, 86, 68, 46, 30, 20, 22, 24, 176, 84, 98, 38, 296, 76, 15, 108,
#        120, 57, 82, 168, 162, 54, 48, 100, 36, 78, 40, 44, 62, 110, 42,
#        72], dtype=object)

# %%
# retirarvalores N0 de paginas finais = "---"
excelFile2 = excelFile2[excelFile2['Nº de páginas finais']!="---"]

# %%
# Verificar se tem alguma inconsistencia na planilha Excel - Quantidade de páginas por exemplo
# excelFile2.sort_values('Nº de páginas finais')

# %%
# verifiacando valores nulos
excelFile2.isnull().sum()
# Out:
# ENTIDADE                  6
# PUBLICAÇÃO                6
# Nº de páginas WORD        3
# Nº de páginas estimado    6
# COMPLEXIDADE              6
# FORNECEDOR                3
# Nº DA PLANILHA            6
# STATUS DE PGTO            6
# Nº de páginas finais      5
# dtype: int64

# %%
# retirar registro nulos
excelFile2=excelFile2.dropna()

# %%
# verifiacando valores nulos
excelFile2.isnull().sum()
# Out:
# ENTIDADE                  0
# PUBLICAÇÃO                0
# Nº de páginas WORD        0
# Nº de páginas estimado    0
# COMPLEXIDADE              0
# FORNECEDOR                0
# Nº DA PLANILHA            0
# STATUS DE PGTO            0
# Nº de páginas finais      0
# dtype: int64

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                   object
# PUBLICAÇÃO                 object
# Nº de páginas WORD         object
# Nº de páginas estimado    float64
# COMPLEXIDADE               object
# FORNECEDOR                 object
# Nº DA PLANILHA             object
# STATUS DE PGTO             object
# Nº de páginas finais       object
# dtype: object

# %%
import numpy as np
excelFile2["Nº DA PLANILHA"] = (pd.to_numeric(excelFile2["Nº DA PLANILHA"], errors='coerce').fillna(0).astype(np.int64))#,downcast='integer'))
#excelFile2["Nº DA PLANILHA"] = excelFile2["Nº DA PLANILHA"].astype('int64',errors='ignore')

# %%
excelFile2.dtypes
# Out:
# ENTIDADE                   object
# PUBLICAÇÃO                 object
# Nº de páginas WORD         object
# Nº de páginas estimado    float64
# COMPLEXIDADE               object
# FORNECEDOR                 object
# Nº DA PLANILHA              int64
# STATUS DE PGTO             object
# Nº de páginas finais       object
# dtype: object

# %%
df.dtypes
# Out:
# Nº DA PLANILHA           float64
# Qtd_PG_word               object
# Qtd_carac                  int64
# Qtd_tabela                 int64
# Qtd_image                  int64
# Qtd_estilos                int64
# Data              datetime64[ns]
# dtype: object

# %%
excelFile2
# Out:
#     ENTIDADE                                         PUBLICAÇÃO  \
# 0        CNI                                           Reuso CE
# 1        CNI                                           Reuso PE
# 2        CNI  Processo De Internalização Dos Atos Internacio...
# 3        CNI  Manual de orientações da ouvidoria do Sesi e d...
# 4        CNI  Guia de Propriedade Intelectual para o Jornalista
# ..       ...                                                ...
# 130    SENAI                  Guia de Operacionalização da MSEP
# 131    SENAI               MSEP / 1º Guia da Prática Pedagógica
# 132    SENAI               MSEP / 2º Guia da Prática Pedagógica
# 133    SENAI              Guia de Operalização PSAI Sustentável
# 134    SENAI            Introdução ao método do emprego apoiado
#
#     Nº de páginas WORD  Nº de páginas estimado COMPLEXIDADE    FORNECEDOR  \
# 0                   87                   140.0         Alta      Editorar
# 1                   82                   122.0         Alta      Editorar
# 2                   41                    70.0        Média      Editorar
# 3                   30                    45.0        Baixa      Editorar
# 4                   36                    48.0        Baixa      Editorar
# ..                 ...                     ...          ...           ...
# 130                 56                   104.0         Alta  Icomunicação
# 131                 38                    48.0        Baixa  Icomunicação
# 132                 33                    44.0        Baixa  Icomunicação
# 133                 33                    72.0        Baixa  Icomunicação
# 134                 12                    24.0        Baixa  Icomunicação
#
#      Nº DA PLANILHA STATUS DE PGTO Nº de páginas finais
# 0            224323           Pago                  140
# 1            224325           Pago                  122
# 2            225392           Pago                   52
# 3            225507           Pago                   32
# 4            225531           Pago                   48
# ..              ...            ...                  ...
# 130          235514           Pago                   72
# 131          235700           Pago                   44
# 132          235701           Pago                   40
# 133          235710           Pago                   48
# 134          235813           Pago                   24
#
# [128 rows x 9 columns]

# %%
df
# Out:
#      Nº DA PLANILHA Qtd_PG_word  Qtd_carac  Qtd_tabela  Qtd_image  \
# 0          228354.0          76     129122          14         10
# 1          235502.0          24      31123          21         17
# 2          232098.0         195     413596          26         20
# 3          225392.0          30      41144          28         24
# 4          228307.0          62      43155          40         73
# ..              ...         ...        ...         ...        ...
# 116        235811.0          34      29372         562        574
# 117        233887.0          28      47904         567        579
# 118        235495.0          39      31612         577        592
# 119        233906.0          78     118624         580        661
# 120        236025.0          24      33141         585        666
#
#      Qtd_estilos       Data
# 0             26 2019-02-27
# 1             23 2020-05-27
# 2             19 2019-09-16
# 3             23 2018-11-07
# 4             25 2019-02-26
# ..           ...        ...
# 116           18 2020-08-03
# 117           14 2020-02-05
# 118           25 2020-05-25
# 119           19 2020-03-09
# 120           19 2020-09-16
#
# [121 rows x 7 columns]

# %%
# verificando quantidade de linhas
df['Nº DA PLANILHA'].count()
# Out:
# 120

# %%
# -----> verificar valores NAN 
df.isnull().sum()
# Out:
# Nº DA PLANILHA    1
# Qtd_PG_word       0
# Qtd_carac         0
# Qtd_tabela        0
# Qtd_image         0
# Qtd_estilos       0
# Data              0
# dtype: int64

# %%
# verificando quantidade de linhas com o coluna N0. da planilha igual a NaN
df[df['Nº DA PLANILHA'].isnull()]
# Out:
#     Nº DA PLANILHA Qtd_PG_word  Qtd_carac  Qtd_tabela  Qtd_image  Qtd_estilos  \
# 46             NaN         143     258920         427        690            5
#
#          Data
# 46 2019-02-05

# %%
# verificando quantidade de linhas

excelFile2['Nº DA PLANILHA'].count()
# Out:
# 128

# %%
# -----> verificar valores NAN 
excelFile2.isnull().sum()
# Out:
# ENTIDADE                  0
# PUBLICAÇÃO                0
# Nº de páginas WORD        0
# Nº de páginas estimado    0
# COMPLEXIDADE              0
# FORNECEDOR                0
# Nº DA PLANILHA            0
# STATUS DE PGTO            0
# Nº de páginas finais      0
# dtype: int64

# %%
# verificando quantidade de linhas com o coluna N0. da planilha igual a NaN

excelFile2[excelFile2['Nº DA PLANILHA'].isnull()]
# Out:
# Empty DataFrame
# Columns: [ENTIDADE, PUBLICAÇÃO, Nº de páginas WORD, Nº de páginas estimado, COMPLEXIDADE, FORNECEDOR, Nº DA PLANILHA, STATUS DE PGTO, Nº de páginas finais]
# Index: []

# %%
# UNIR arquivo do NGE com o método de leitura dos arquivos Word
#
# Atenção >>>>>>>> alguns arquivos não passaram pelo método de leitura dos arquivos word e irão gerar valores NAN
#
df_final = pd.merge(excelFile2, df, on=['Nº DA PLANILHA'], how='left')

# %% [markdown]
# # PRECISO REVISAR O MERGE, POIS A COLUNA DATA DO DATASET df NÃO FOI ENCORPORADO NO DATASET df_final

# %%
# verificando quantidade de linhas

df_final['Nº DA PLANILHA'].count()
# Out:
# 131

# %%
# colocando ordem de apresentação das colunas adequada
excelFile2.columns
# Out:
# Index(['ENTIDADE', 'PUBLICAÇÃO', 'Nº de páginas WORD',
#        'Nº de páginas estimado', 'COMPLEXIDADE', 'FORNECEDOR',
#        'Nº DA PLANILHA', 'STATUS DE PGTO', 'Nº de páginas finais'],
#       dtype='object')

# %%
df.columns
# Out:
# Index(['Nº DA PLANILHA', 'Qtd_PG_word', 'Qtd_carac', 'Qtd_tabela', 'Qtd_image',
#        'Qtd_estilos', 'Data'],
#       dtype='object')

# %%
df_final.columns
# Out:
# Index(['ENTIDADE', 'PUBLICAÇÃO', 'Nº de páginas WORD',
#        'Nº de páginas estimado', 'COMPLEXIDADE', 'FORNECEDOR',
#        'Nº DA PLANILHA', 'STATUS DE PGTO', 'Nº de páginas finais',
#        'Qtd_PG_word', 'Qtd_carac', 'Qtd_tabela', 'Qtd_image', 'Qtd_estilos',
#        'Data'],
#       dtype='object')

# %%
# colocando ordem de apresentação das colunas adequada

#colunas_final = ['Nº DA PLANILHA','ENTIDADE',  'FORNECEDOR','COMPLEXIDADE', 'STATUS DE PGTO',  'Nº de páginas WORD','Nº de páginas estimado', 'Qtd_carac','Qtd_tabela', 'Qtd_image','Nº de páginas finais' ]
colunas_final = ['Nº DA PLANILHA','ENTIDADE',  'FORNECEDOR','COMPLEXIDADE', 'STATUS DE PGTO',  'Nº de páginas WORD','Nº de páginas estimado', "Qtd_PG_word", 'Qtd_carac','Qtd_tabela', 'Qtd_image',"Qtd_estilos",'Nº de páginas finais' ]
df_final = df_final[colunas_final]

# %%
df_final.count()
# Out:
# Nº DA PLANILHA            131
# ENTIDADE                  131
# FORNECEDOR                131
# COMPLEXIDADE              131
# STATUS DE PGTO            131
# Nº de páginas WORD        131
# Nº de páginas estimado    131
# Qtd_PG_word               114
# Qtd_carac                 114
# Qtd_tabela                114
# Qtd_image                 114
# Qtd_estilos               114
# Nº de páginas finais      131
# dtype: int64

# %%
# -----> verificar valores NAN 
df_final.isnull().sum()
# OS REGISTROS COM NAN NESSE CASO FORAM OS ARQUIVOS QUE ESTAVAM NO ARQUIVO EXCEL 
# E QUE NÃO TINHAM O AQUIVO WORD CORRESPONDENTE , OU SEJA NÃO FOI ENCONTRADO NA PASTA
# Out:
# Nº DA PLANILHA             0
# ENTIDADE                   0
# FORNECEDOR                 0
# COMPLEXIDADE               0
# STATUS DE PGTO             0
# Nº de páginas WORD         0
# Nº de páginas estimado     0
# Qtd_PG_word               17
# Qtd_carac                 17
# Qtd_tabela                17
# Qtd_image                 17
# Qtd_estilos               17
# Nº de páginas finais       0
# dtype: int64

# %%
df_final[df_final['Nº DA PLANILHA'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Nº DA PLANILHA, ENTIDADE, FORNECEDOR, COMPLEXIDADE, STATUS DE PGTO, Nº de páginas WORD, Nº de páginas estimado, Qtd_PG_word, Qtd_carac, Qtd_tabela, Qtd_image, Qtd_estilos, Nº de páginas finais]
# Index: []

# %%
# lista dos arquivos do Excel que não tem arquivo do Word correspondente
    
    
df_final[df_final['Qtd_carac'].isnull()]
# Out:
#      Nº DA PLANILHA ENTIDADE    FORNECEDOR COMPLEXIDADE STATUS DE PGTO  \
# 4            225507      CNI      Editorar        Baixa           Pago
# 9            227979      CNI      Editorar         Alta           Pago
# 13           228444     SESI      Editorar         Alta           Pago
# 34           231378     SESI      Editorar         Alta           Pago
# 36                1      CNI      Editorar        Média           Pago
# 37                2      CNI      Editorar        Média           Pago
# 50           232328      CNI      Editorar        Baixa           Pago
# 60           233002    SENAI      Editorar         Alta           Pago
# 68           228346      CNI  Icomunicação         Alta           Pago
# 69           227031      CNI  Icomunicação         Alta           Pago
# 90           233910      CNI      Editorar        Baixa           Pago
# 93           233839    SENAI      Editorar         Alta           Pago
# 95           235193      CNI      Editorar         Alta           Pago
# 96           235195     SESI      Editorar        Média           Pago
# 97           235195    SENAI      Editorar            -           Pago
# 98           235195      IEL      Editorar            -           Pago
# 130          235813    SENAI  Icomunicação        Baixa           Pago
#
#     Nº de páginas WORD  Nº de páginas estimado Qtd_PG_word  Qtd_carac  \
# 4                   30                    45.0         NaN        NaN
# 9                   46                    98.0         NaN        NaN
# 13                  45                    70.0         NaN        NaN
# 34                  71                    71.0         NaN        NaN
# 36                  41                    48.0         NaN        NaN
# 37                  41                    48.0         NaN        NaN
# 50                  64                    48.0         NaN        NaN
# 60                 543                   400.0         NaN        NaN
# 68                 316                   440.0         NaN        NaN
# 69                 196                   196.0         NaN        NaN
# 90                  15                    15.0         NaN        NaN
# 93                  70                   120.0         NaN        NaN
# 95                  50                    80.0         NaN        NaN
# 96                  55                    71.0         NaN        NaN
# 97                  55                    71.0         NaN        NaN
# 98                  55                    71.0         NaN        NaN
# 130                 12                    24.0         NaN        NaN
#
#      Qtd_tabela  Qtd_image  Qtd_estilos Nº de páginas finais
# 4           NaN        NaN          NaN                   32
# 9           NaN        NaN          NaN                   92
# 13          NaN        NaN          NaN                   70
# 34          NaN        NaN          NaN                   71
# 36          NaN        NaN          NaN                   43
# 37          NaN        NaN          NaN                   43
# 50          NaN        NaN          NaN                   54
# 60          NaN        NaN          NaN                  386
# 68          NaN        NaN          NaN                  296
# 69          NaN        NaN          NaN                  196
# 90          NaN        NaN          NaN                   15
# 93          NaN        NaN          NaN                  120
# 95          NaN        NaN          NaN                   66
# 96          NaN        NaN          NaN                   57
# 97          NaN        NaN          NaN                   57
# 98          NaN        NaN          NaN                   57
# 130         NaN        NaN          NaN                   24

# %%
# retirar registro nulos , OU SEJA RETIRAR OS DADOS QUE NÃO TINHAM NA PASTA DO WORD
df_final=df_final.dropna()
# APAGOU AS LINHAS COM NAN

# outra alternativa seria preencher com valores as celulas com NaN 
# df_final.fillna(df_final.mean(0))

# %%
# -----> verificar valores NAN 
df_final.isnull().sum()
# Out:
# Nº DA PLANILHA            0
# ENTIDADE                  0
# FORNECEDOR                0
# COMPLEXIDADE              0
# STATUS DE PGTO            0
# Nº de páginas WORD        0
# Nº de páginas estimado    0
# Qtd_PG_word               0
# Qtd_carac                 0
# Qtd_tabela                0
# Qtd_image                 0
# Qtd_estilos               0
# Nº de páginas finais      0
# dtype: int64

# %%
df_final.count()
# Out:
# Nº DA PLANILHA            114
# ENTIDADE                  114
# FORNECEDOR                114
# COMPLEXIDADE              114
# STATUS DE PGTO            114
# Nº de páginas WORD        114
# Nº de páginas estimado    114
# Qtd_PG_word               114
# Qtd_carac                 114
# Qtd_tabela                114
# Qtd_image                 114
# Qtd_estilos               114
# Nº de páginas finais      114
# dtype: int64

# %%
df_final
# Out:
#      Nº DA PLANILHA ENTIDADE    FORNECEDOR COMPLEXIDADE STATUS DE PGTO  \
# 0            224323      CNI      Editorar         Alta           Pago
# 1            224325      CNI      Editorar         Alta           Pago
# 2            225392      CNI      Editorar        Média           Pago
# 3            225392      CNI      Editorar        Média           Pago
# 5            225531      CNI      Editorar        Baixa           Pago
# ..              ...      ...           ...          ...            ...
# 125          235513    SENAI  Icomunicação        Média           Pago
# 126          235514    SENAI  Icomunicação         Alta           Pago
# 127          235700    SENAI  Icomunicação        Baixa           Pago
# 128          235701    SENAI  Icomunicação        Baixa           Pago
# 129          235710    SENAI  Icomunicação        Baixa           Pago
#
#     Nº de páginas WORD  Nº de páginas estimado Qtd_PG_word  Qtd_carac  \
# 0                   87                   140.0          87   116142.0
# 1                   82                   122.0          82   108307.0
# 2                   41                    70.0          30    41144.0
# 3                   41                    70.0          42    62913.0
# 5                   36                    48.0          36    37548.0
# ..                 ...                     ...         ...        ...
# 125                 49                    96.0          52    56538.0
# 126                 56                   104.0          41    51127.0
# 127                 38                    48.0          37    40157.0
# 128                 33                    44.0          33    42499.0
# 129                 33                    72.0          33    28573.0
#
#      Qtd_tabela  Qtd_image  Qtd_estilos Nº de páginas finais
# 0         505.0      742.0         60.0                  140
# 1          76.0       94.0         69.0                  122
# 2          28.0       24.0         23.0                   52
# 3         432.0      696.0         21.0                   52
# 5         270.0      456.0         17.0                   48
# ..          ...        ...          ...                  ...
# 125       184.0      339.0         22.0                   52
# 126       446.0      474.0         18.0                   72
# 127       410.0      426.0         16.0                   44
# 128       349.0      394.0         15.0                   40
# 129       519.0      520.0         15.0                   48
#
# [114 rows x 13 columns]

# %%
#print(df_final["qtd_pag_word"],(df_final["qtd_carc"]/1430))

# %%
# reindexar o index devido ter deletado algumas linhas
df_final.reset_index(drop=True, inplace=True)

# %%
#colunas_final = ['Nº DA PLANILHA','ENTIDADE', 'PUBLICAÇÃO', 'FORNECEDOR','COMPLEXIDADE', 'STATUS DE PGTO', 'Data', 'Nº de páginas WORD', 'Nº de páginas estimado', 'Qtd_carac','Qtd_tabela', 'Qtd_image','Nº de páginas finais' ]
#df_final_num = df_final[colunas_final]

# %%
df_final.dtypes
# Out:
# Nº DA PLANILHA              int64
# ENTIDADE                   object
# FORNECEDOR                 object
# COMPLEXIDADE               object
# STATUS DE PGTO             object
# Nº de páginas WORD         object
# Nº de páginas estimado    float64
# Qtd_PG_word                object
# Qtd_carac                 float64
# Qtd_tabela                float64
# Qtd_image                 float64
# Qtd_estilos               float64
# Nº de páginas finais       object
# dtype: object

# %%
df_final.head()
# Out:
#    Nº DA PLANILHA ENTIDADE FORNECEDOR COMPLEXIDADE STATUS DE PGTO  \
# 0          224323      CNI   Editorar         Alta           Pago
# 1          224325      CNI   Editorar         Alta           Pago
# 2          225392      CNI   Editorar        Média           Pago
# 3          225392      CNI   Editorar        Média           Pago
# 4          225531      CNI   Editorar        Baixa           Pago
#
#   Nº de páginas WORD  Nº de páginas estimado Qtd_PG_word  Qtd_carac  \
# 0                 87                   140.0          87   116142.0
# 1                 82                   122.0          82   108307.0
# 2                 41                    70.0          30    41144.0
# 3                 41                    70.0          42    62913.0
# 4                 36                    48.0          36    37548.0
#
#    Qtd_tabela  Qtd_image  Qtd_estilos Nº de páginas finais
# 0       505.0      742.0         60.0                  140
# 1        76.0       94.0         69.0                  122
# 2        28.0       24.0         23.0                   52
# 3       432.0      696.0         21.0                   52
# 4       270.0      456.0         17.0                   48

# %%
# alterar campos typo string para categóricos 
df_final['ENTIDADE'] = df_final['ENTIDADE'].astype('category')
df_final['COMPLEXIDADE'] = df_final['COMPLEXIDADE'].astype('category')
df_final['FORNECEDOR'] = df_final['FORNECEDOR'].astype('category')
df_final['STATUS DE PGTO'] = df_final['STATUS DE PGTO'].astype('category')

# %%
# SOBRE O AVISO: A value is trying to be set on a copy of a slice from a dataframe
# https://paulovasconcellos.com.br/o-que-%C3%A9-a-value-is-trying-to-be-set-on-a-copy-of-a-slice-from-a-dataframe-e85f744d8be1

# %%
# alterar campos typo categóricos para numérico
# aplicando .cat.codes em cada uma dessas colunas
df_final['ENTIDADE'] = df_final['ENTIDADE'].cat.codes
df_final['COMPLEXIDADE'] = df_final['COMPLEXIDADE'].cat.codes
df_final['FORNECEDOR'] = df_final['FORNECEDOR'].cat.codes
df_final['STATUS DE PGTO'] = df_final['STATUS DE PGTO'].cat.codes

# %%
df_final['Nº de páginas finais'].unique()
# Out:
# array(['140', '122', '52', '48', 88, '66', '82', '70', '96', '18', '40',
#        '46', '68', '34', '28', '86', '84', '110', '116', '98', '340',
#        '72', '112', '92', '100', '76', '212', '74', '38', '42', '104',
#        '126', 1, 52, 66, 86, 68, 46, 30, 20, 22, 24, 176, 84, 98, 38, 296,
#        76, 108, 82, 168, 162, 54, 48, 100, 36, 78, 40, 44, 62, 110, 42,
#        72], dtype=object)

# %%
df_final['Nº de páginas WORD'] = df_final['Nº de páginas WORD'].astype('int')

# %%
# Verificar se tem alguma inconsistencia na planilha Excel - Quantidade de páginas por exemplo
df_final.sort_values('Nº de páginas WORD')

# eliminar linhas com menos de 10 páginas
filtro  = df_final['Nº de páginas WORD'] > 10
df_final = df_final[filtro]

# %%
df_final.dtypes
# Out:
# Nº DA PLANILHA              int64
# ENTIDADE                     int8
# FORNECEDOR                   int8
# COMPLEXIDADE                 int8
# STATUS DE PGTO               int8
# Nº de páginas WORD          int64
# Nº de páginas estimado    float64
# Qtd_PG_word                object
# Qtd_carac                 float64
# Qtd_tabela                float64
# Qtd_image                 float64
# Qtd_estilos               float64
# Nº de páginas finais       object
# dtype: object

# %%
df_final.head()
# Out:
#    Nº DA PLANILHA  ENTIDADE  FORNECEDOR  COMPLEXIDADE  STATUS DE PGTO  \
# 0          224323         0           0             1               0
# 1          224325         0           0             1               0
# 2          225392         0           0             3               0
# 3          225392         0           0             3               0
# 4          225531         0           0             2               0
#
#    Nº de páginas WORD  Nº de páginas estimado Qtd_PG_word  Qtd_carac  \
# 0                  87                   140.0          87   116142.0
# 1                  82                   122.0          82   108307.0
# 2                  41                    70.0          30    41144.0
# 3                  41                    70.0          42    62913.0
# 4                  36                    48.0          36    37548.0
#
#    Qtd_tabela  Qtd_image  Qtd_estilos Nº de páginas finais
# 0       505.0      742.0         60.0                  140
# 1        76.0       94.0         69.0                  122
# 2        28.0       24.0         23.0                   52
# 3       432.0      696.0         21.0                   52
# 4       270.0      456.0         17.0                   48

# %%
df_final.columns
# Out:
# Index(['Nº DA PLANILHA', 'ENTIDADE', 'FORNECEDOR', 'COMPLEXIDADE',
#        'STATUS DE PGTO', 'Nº de páginas WORD', 'Nº de páginas estimado',
#        'Qtd_PG_word', 'Qtd_carac', 'Qtd_tabela', 'Qtd_image', 'Qtd_estilos',
#        'Nº de páginas finais'],
#       dtype='object')

# %%
# trocar type float por int
#df_final['Nº DA PLANILHA'] = df_final['Nº DA PLANILHA'].astype('int')
#df_final['Nº DA PLANILHA'] = df_final['Nº DA PLANILHA'].astype('int')

# %%
# inserir zeros no lugar do valor NAN
#df_final['Qtd_carac']= df_final['Qtd_carac'].fillna(0)
#df_final['Qtd_tabela'] = df_final['Qtd_tabela'].fillna(0)
#df_final['Qtd_image'] = df_final['Qtd_image'].fillna(0)

# %%
# trocar type float por int
#df_final['Nº de páginas estimado'] = df_final['Nº de páginas estimado'].astype('int')
df_final['Qtd_carac'] = df_final['Qtd_carac'].astype('int')
df_final["Qtd_PG_word"] = df_final["Qtd_PG_word"].astype('int')
df_final['Qtd_tabela'] = df_final['Qtd_tabela'].astype('int')
df_final['Qtd_image'] = df_final['Qtd_image'].astype('int')

df_final['Nº de páginas finais'] = df_final['Nº de páginas finais'].astype('int')
# Out:
# <ipython-input-200-22ece583bb12>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Qtd_carac'] = df_final['Qtd_carac'].astype('int')
# <ipython-input-200-22ece583bb12>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final["Qtd_PG_word"] = df_final["Qtd_PG_word"].astype('int')
# <ipython-input-200-22ece583bb12>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Qtd_tabela'] = df_final['Qtd_tabela'].astype('int')
# <ipython-input-200-22ece583bb12>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Qtd_image'] = df_final['Qtd_image'].astype('int')
# <ipython-input-200-22ece583bb12>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['Nº de páginas finais'] = df_final['Nº de páginas finais'].astype('int')

# %%
df_final.columns
# Out:
# Index(['Nº DA PLANILHA', 'ENTIDADE', 'FORNECEDOR', 'COMPLEXIDADE',
#        'STATUS DE PGTO', 'Nº de páginas WORD', 'Nº de páginas estimado',
#        'Qtd_PG_word', 'Qtd_carac', 'Qtd_tabela', 'Qtd_image', 'Qtd_estilos',
#        'Nº de páginas finais'],
#       dtype='object')

# %%
df_final.dtypes
# Out:
# Nº DA PLANILHA              int64
# ENTIDADE                     int8
# FORNECEDOR                   int8
# COMPLEXIDADE                 int8
# STATUS DE PGTO               int8
# Nº de páginas WORD          int64
# Nº de páginas estimado    float64
# Qtd_PG_word                 int64
# Qtd_carac                   int64
# Qtd_tabela                  int64
# Qtd_image                   int64
# Qtd_estilos               float64
# Nº de páginas finais        int64
# dtype: object

# %%
#renomear colunas
#df_final.rename(columns={'Nº DA PLANILHA': 'id','ENTIDADE':"entidade",'FORNECEDOR':"fornecedor", 'COMPLEXIDADE':"complexidade",
#                         'STATUS DE PGTO':"stat_pagto",'Nº de páginas WORD':"qtd_pag_word", 
#                         'Nº de páginas estimado':"qtd_pag_estimado", 'Qtd_carac':"qtd_carc",
#       'Qtd_tabela':"qtd_tabela", 'Qtd_image': "qtd_image", 'Nº de páginas finais':"pag_final"} , inplace = True)

df_final.rename(columns={'Nº DA PLANILHA': 'id','ENTIDADE':"entidade",'FORNECEDOR':"fornecedor", 'COMPLEXIDADE':"complexidade",
                         'STATUS DE PGTO':"stat_pagto",'Nº de páginas WORD':"qtd_pag_word", 
                         'Nº de páginas estimado':"qtd_pag_estimado", 'Qtd_carac':"qtd_carc","Qtd_PG_word":"qtd_pg_word",
       'Qtd_tabela':"qtd_tabela", 'Qtd_image': "qtd_image","Qtd_estilos":"qtd_estilos", 'Nº de páginas finais':"pag_final"} , inplace = True)
# Out:
# /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages/pandas/core/frame.py:4293: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
print(len(df_final[df_final["pag_final"]>149]))
print(len(df_final[(df_final["pag_final"]>59) & (df_final["pag_final"]<150)]))
print(len(df_final[df_final["pag_final"]<60]))
# Out:
# 7
# 58
# 47

# %%
df_final[df_final["pag_final"]>120]
# Out:
#         id  entidade  fornecedor  complexidade  stat_pagto  qtd_pag_word  \
# 0   224323         0           0             1           0            87
# 1   224325         0           0             1           0            82
# 24  231201         0           0             0           0           214
# 33       3         2           0             1           0           216
# 41  232098         0           0             1           0           195
# 55  233263         0           0             1           0           112
# 71  233884         0           0             1           0           158
# 77  233908         0           0             1           0           207
# 86       0         1           0             1           0           168
# 87       0         2           0             1           0           162
#
#     qtd_pag_estimado  qtd_pg_word  qtd_carc  qtd_tabela  qtd_image  \
# 0              140.0           87    116142         505        742
# 1              122.0           82    108307          76         94
# 24             420.0          214    425343         350        554
# 33             300.0          216    346608         157        339
# 41             360.0          195    413596          26         20
# 55             160.0          112    223019         529        788
# 71             220.0          131    208458         344        392
# 77             310.0          207    571640         474        482
# 86             168.0           70     95656         220        438
# 87             162.0           70     95656         220        438
#
#     qtd_estilos  pag_final
# 0          60.0        140
# 1          69.0        122
# 24         19.0        340
# 33         54.0        212
# 41         19.0        340
# 55         25.0        126
# 71          7.0        176
# 77         24.0        296
# 86         17.0        168
# 87         17.0        162

# %%
df_final['tamanho_livro'] = 'NaN'
for index, row in df_final.iterrows():
    #print(row["pag_final"])
    if row["pag_final"]>119:
        df_final.loc[index,'tamanho_livro'] =  2
    elif row["pag_final"]>59 & row["pag_final"]<120:
        df_final.loc[index,'tamanho_livro'] =  1
    else:  
        df_final.loc[index,'tamanho_livro'] =  0
# Out:
# <ipython-input-206-52187eb34a0c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_final['tamanho_livro'] = 'NaN'
# /Users/wpessoa/miniconda3/envs/py3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
df_final[df_final['tamanho_livro']==0]
# Out:
#          id  entidade  fornecedor  complexidade  stat_pagto  qtd_pag_word  \
# 4    225531         0           0             2           0            36
# 10   228437         0           0             2           0            18
# 11   228603         0           0             2           0            33
# 14   229294         0           0             2           0            22
# 22   230385         0           0             2           0            38
# 25   230874         0           0             2           0            22
# 39   231928         0           0             2           0            34
# 40   231931         0           0             2           0            33
# 42   232174         0           0             2           0            29
# 47   232393         2           0             2           0            29
# 54   233069         0           0             2           0            24
# 57   233405         0           0             2           0            19
# 58   233474         0           0             1           0            36
# 70   233892         1           0             2           0            19
# 89   235469         0           0             2           0            40
# 98   235534         0           0             2           0            29
# 99   235650         0           0             2           0            39
# 108  235831         0           0             2           0            28
# 112  235701         1           1             2           0            33
# 113  235710         1           1             2           0            33
#
#      qtd_pag_estimado  qtd_pg_word  qtd_carc  qtd_tabela  qtd_image  \
# 4                48.0           36     37548         270        456
# 10               18.0           80    145034         175        370
# 11               48.0           13     45943         114        132
# 14               46.0           18     16595         134        152
# 22               56.0           38     37614         542        795
# 25               48.0           22     19773         411        648
# 39               48.0           34     56358         104        119
# 40               48.0           33     53352         325        526
# 42               48.0           29     24953         422        682
# 47               48.0           29     25364         560        839
# 54               44.0           24     19149         211        400
# 57               45.0           19     17160         209        398
# 58               68.0           36     33348         213        416
# 70               45.0           17     12032         248        366
# 89               70.0           24     28880         539        545
# 98               48.0           29     23931          12         15
# 99               68.0           39     36051         351        397
# 108              48.0           28     25136         425        439
# 112              44.0           33     42499         349        394
# 113              72.0           33     28573         519        520
#
#      qtd_estilos  pag_final tamanho_livro
# 4           17.0         48             0
# 10          35.0         18             0
# 11          22.0         40             0
# 14          17.0         34             0
# 22          20.0         48             0
# 25          22.0         34             0
# 39          25.0         48             0
# 40          21.0         42             0
# 42          19.0         48             0
# 47          16.0         40             0
# 54          22.0         40             0
# 57          15.0         34             0
# 58          48.0         48             0
# 70          32.0         24             0
# 89          41.0         48             0
# 98          20.0         40             0
# 99          30.0         48             0
# 108         17.0         42             0
# 112         15.0         40             0
# 113         15.0         48             0

# %%
# gerar arquivo csv para arquivo tratado

df_final.to_csv("nge_dados_input2.csv",index=False )
df_final.to_excel("nge_dados_input2.xlsx",index=False,header=True )

#data = pd.read_csv("nge_dados_input.csv")
#df_final.to_csv(index=False)
#df_final.to_csv("nge_dados_input.csv", data = imprimir_ano)

# %%
# FIM MÉTODO..... RODADR O TRINEMANTO DE MACHINE LEARNING =>   machine_learning_NGE
